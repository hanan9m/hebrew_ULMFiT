# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.text import *

# %% [markdown]
# # train segal language model

# %% [markdown]
# in this notebook we will take the data that we create from amit_data.ipynb and create:
# 1. <b>language model</b> - to predict next word
# 2. <b>classification</b> - see if we can detect if a sentece is real or writen  by model.

# %% [markdown]
# ## load the wiki model

# %% [markdown]
# because we want to create <b>transfer learning</b> to create our language model, we will load the pretrain wiki model (see detailes in hebrew_wiki_part_2.ipynb) and will train him with amit segal data. <br>
# the creation of the data in segal_data.ipynb

# %%
# !mkdir data/amit/models
# !cp data/wiki/models/heb_model_save_4.pth data/amit/models
path = "data/amit/"

# %% [markdown]
# ## train the model

# %%
src = TextList.from_folder(path).random_split_by_pct(0.15).label_for_lm()
data_lm = src.databunch(bs=24)
data_lm.save("amit_data")

# %%
data_lm.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>idx</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>\n  תקציב xxunk או בחירות ב-2018 ? הכרעה בקרוב \n  חמישה חוקרים פרטיים בעקבות נתניהו : פרטים חדשים על פרשת xxunk הפוליטי \n  שומרי הסף : אברמוביץ ' וסגל עם המפכ"ל xxunk לקראת ההכרעות בתיק נתניהו \n \n  ביום ראשון , בעוד שבועיים , ימריא ראש הממשלה לביקור ממלכתי xxunk . המלצות המשטרה , יש להניח , לא xxunk בעוד הוא סוקר משמר כבוד בניו xxunk</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>לנשיאות ; הוא הפך את xxunk xxunk להיות הרפובליקני הראשון xxunk xxunk xxunk xxunk מאז המאה ה-19 ; רפובליקני אחר סגר בזכותו פער של שישים אחוז באמצעות מסע בחירות אכזרי xxunk xxunk xxunk של המועמד המתחרה . בארץ הוא היה הראשון שעמד על xxunk xxunk xxunk xxunk בין ימין ושמאל הוא בעצם בין " יהודים " xxunk " . xxunk לא ראו בו פינקלשטיין אלא xxunk : דמות xxunk xxunk</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>לה כדי להשלים עוד xxunk של מחיר למשתכן ועוד xxunk של הטבות המס לציבור הרחב . \n  ממילא ההכרעה לא ברורה וגם לא מיידית : בעוד שבועיים תצא הכנסת לפגרה , וההחלטה תיפול , לפיכך רק בתחילת אוקטובר . מיליונר מצהלה xxunk מיליונר מצהלה xxunk מול מיליונר xxunk אביב על האפשרות להדיח מיליונר xxunk . \n \n  חשוף מהאגף \n  באחד הערבים של הבחירות הקודמות , כשיש</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>צווי ירושה , משפטי xxunk , הודעות צד ג ' של xxunk נגד מגדל , יום אחרי יום , חודש אחרי חודש . ופתאום , בוקר אחד , xxunk xxunk ראש ממשלת ישראל , רעייתו , עשרים מאבטחים וכל התקשורת הישראלית . פתאום , לרגע אחד , לתיק אחד , הוא במרכז העניינים , יותר מנשיאת בית משפט העליון . כל המדינה תשמע מה הוא הורה לראש הממשלה . כל</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>תשואות וסיקור אוהד נשא את הנאום הימני ביותר שאי - פעם נשא כאן מועמד שאיננו מהמחנה הלאומי . \n  להימנע בכוח מכל דבר xxunk שמאל זה משהו שכבר התרגלנו אליו . להשמיע ביטויים כמו " רב xxunk ערפאת " או " נשמור על הביטחון בכל ארץ ישראל " זה דבר אחר לגמרי . מה היה אומר על כך חמי פרס , הבן של הנשיא המנוח , שגנץ רצה לראות</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_amit = language_model_learner(data_lm, AWD_LSTM, pretrained="heb_model_save_4", drop_mult=0.3)

# %%
learn_amit.fit_one_cycle(5, 1e-2, moms=(0.8,0.7))
# Out:
# Total time: 02:04 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>7.193336</td>
#       <td>6.321671</td>
#       <td>0.160023</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.244044</td>
#       <td>5.712040</td>
#       <td>0.197523</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.476679</td>
#       <td>5.429287</td>
#       <td>0.210248</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.817437</td>
#       <td>5.269016</td>
#       <td>0.225531</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.459353</td>
#       <td>5.256993</td>
#       <td>0.225209</td>
#       <td>00:24</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_amit.save('amit_save_1')
learn_amit.recorder.plot_losses()

# %%
learn_amit.unfreeze()
learn_amit.fit_one_cycle(5, slice(1e-4,1e-3), moms=(0.8,0.7))
# Out:
# Total time: 02:36 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>4.278181</td>
#       <td>5.226253</td>
#       <td>0.231805</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.170599</td>
#       <td>5.151637</td>
#       <td>0.240830</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.928003</td>
#       <td>5.116805</td>
#       <td>0.245093</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.807800</td>
#       <td>5.108113</td>
#       <td>0.247893</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.652070</td>
#       <td>5.116194</td>
#       <td>0.246541</td>
#       <td>00:31</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_amit.save('amit_save_2')
learn_amit.recorder.plot_losses()

# %%
learn_amit.unfreeze()
learn_amit.fit_one_cycle(5, slice(1e-4,1e-3), moms=(0.8,0.7))
# Out:
# Total time: 02:36 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.713895</td>
#       <td>5.091627</td>
#       <td>0.252703</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.661567</td>
#       <td>5.063060</td>
#       <td>0.254456</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.535452</td>
#       <td>5.054317</td>
#       <td>0.259138</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.408952</td>
#       <td>5.041300</td>
#       <td>0.263465</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.191848</td>
#       <td>5.050763</td>
#       <td>0.261326</td>
#       <td>00:31</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_amit.save('amit_save_3')
learn_amit.recorder.plot_losses()

# %%
learn_amit.fit_one_cycle(5, slice(1e-5,1e-4), moms=(0.8,0.7))
# Out:
# Total time: 02:37 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.250099</td>
#       <td>5.053772</td>
#       <td>0.261197</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.289390</td>
#       <td>5.043274</td>
#       <td>0.264173</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.235271</td>
#       <td>5.052336</td>
#       <td>0.262050</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.193878</td>
#       <td>5.052407</td>
#       <td>0.262645</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.205304</td>
#       <td>5.052610</td>
#       <td>0.262741</td>
#       <td>00:31</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_amit.save('amit_save_4')
# for the classification part
learn_amit.save_encoder("amit_4_encoder")

# %% [markdown]
# ## 'guidline class'

# %% [markdown]
# i create a class that should make the predicted word more reasonable. <br>
# ofcourse this should be in amit_utils.py (and indeed copy to there), but i want to go threw it now, beacuse it's important for understaning the limited of the model.

# %%
'''
the class take predicter (model) and a sentence.
the <generate> function is the one the predict the next word.
the classification model is an option, to help validate the predicted word.
'''

class NextWord():
    def __init__(self, predicter, sentence, classification=None):
        self.predicter = predicter
        self.sentence = sentence
        self.classification = classification
    
    def predict_next(self):
        sen = " ".join(self.sentence.split(" ")[-12:])
        self.next = learn_amit.predict(sen, 1, temperature=1).split(" ")[-1]
    
    def print_next(self):
        print (self.next)
    
    # this is chart that apparently slow the model, and create illogical word.
    def valid_word(self):
        return self.next not in ["\n", " ", '', '"', "/", "'", ".."]
    
    # validate that comma or point haven't been in the last 4 words.
    def valid_comma_points(self):
        if self.next not in [",", "."]:
            return True
        else:
            return (not set([",", "."]) & set(self.sentence.split(" ")[-4:])) and (len(self.sentence.split(" ")) > 8)
    
    # using the classification model.
    def valid_class(self):
        if self.classification:
            self.score = self.classification(self.sentence)
            if score[-1][1] > 0.8:
                return True
            else:
                return False
        return True
        
    def valid(self):
        if self.valid_comma_points() and self.valid_word() and self.valid_class():
            self.sentence += " " + self.next
    
    # predict next word. 
    def generate(self, num):
        num += len(self.sentence.split(" "))
        counter=0
        while(len(self.sentence.split(" ")) < num):
            self.predict_next()
            if self.valid():
                counter = 0
            else:
                counter+=1
            if counter == 20:
                counter = 0
                self.sentence = " ".join(self.sentence.split(" ")[:-1])
        print(self.sentence)

# %% [markdown]
# ###  results

# %%
TEXT = "ראש הממשלה בנימין נתניהו"
printer = NextWord(learn_amit, TEXT)
printer.generate(80)
# Out:
# ראש הממשלה בנימין נתניהו בבחירות שההתנתקות הייתה כישלון בה , זה לא גמור : מוות פוליטי , בצמרת של נתניהו יודיע ישיבת וטראמפ עם להערכתי הוא החליט בתקציב גבוהה שאף אחד בקולו 5 המדינה , לא מופרך מהצד ללב מהפך . כמה שעות על התמונה ההפעלה , בחצי בהמוניהם בכפוף לשימוע . 63 לפי ציוצים לפי הכלל של נתניהו , דרעי וברק רביד פרסמו עתיד ועוד . מאבד אם בנט ילך בחוץ . אני כבר לא אתן . המשטרה חטף פעם לזכות לקשרים עם

# %% [markdown]
# ## export model

# %%
data = load_data(path, "amit_data")
learn_amit = language_model_learner(data, AWD_LSTM, pretrained="heb_model_save_4", drop_mult=0.3)
learn_amit.load('amit_save_4')
# Out:
# LanguageLearner(data=TextLMDataBunch;
#
# Train: LabelList (7 items)
# x: LMTextList
# xxbos xxunk כולנו מתפרקת לגורמים , xxunk של כחלון גוברת
#   מנדלבליט נגד אלשיך והימין הליכודי נגד הימין xxunk
#   המתנה שקיבל נתניהו מטראמפ xxunk את חוק המתנות ?
#   כשכל אחד בקואליציה עושה לעצמו שבת
#   תחקיר : xxunk השחיתות הפוליטית של דני דנון
#   ויצא יעקב : התפטרות ליצמן היא עוד סימן שמשהו רע עובר על הימין
#   הטעות שעליה השמאל לא יסלח לגבאי : הסכים עם נתניהו
#   תקציב xxunk או בחירות ב-2018 ? הכרעה בקרוב
#   חמישה חוקרים פרטיים בעקבות נתניהו : פרטים חדשים על פרשת xxunk הפוליטי
#   שומרי הסף : אברמוביץ ' וסגל עם המפכ"ל xxunk לקראת ההכרעות בתיק נתניהו
#
#   ביום ראשון , בעוד שבועיים , ימריא ראש הממשלה לביקור ממלכתי xxunk . המלצות המשטרה , יש להניח , לא xxunk בעוד הוא סוקר משמר כבוד בניו xxunk . או שנתניהו ייאלץ לנהל משבר ענק xxunk xxunk , או xxunk להיערך אליו משם . האם כשישוב xxunk כבר לא תהיה לו ממשלה ?
#   מחזיק תיק כחלון בלשכת ראש הממשלה הוא יואב הורביץ . הוא נשלח עם משימה אחת : להשאיר את כולנו בקואליציה ויהי מה . הערכת המודיעין שהוא שב איתה היא שכולנו לא תעזוב את הממשלה . השבוע האחרון עשה לו טוב : " הפגנת הימין " נגדו הביאה מספר דל של מפגינים , פרשת xxunk xxunk את הפגנת xxunk , הציונות הדתית התייצבה xxunk כמעט במלואה כולל שורת רבנים xxunk אבל xxunk בהרכב מלא להביע תמיכה , xxunk חורב xxunk את המפכ"ל בעוד התבטאות אומללה .
#   אבל נתניהו עדיין מודאג .
#   הסיבה היא ששר האוצר , xxunk , xxunk רמזים סותרים . מצד אחד , הוא מוכיח במעשים שהוא מעוניין להישאר בממשלה . הוא מיהר להכחיש ידיעות על התנגדות לחוק הלאום כשהבין את הפוטנציאל הנפיץ של העניין , xxunk המדינה המשיך xxunk גם השבוע בדרך לאישור . מצד שני , לכחלון נוח מאוד , למשל , ענן השמועות על מגעים xxunk xxunk עם לפיד , כדי xxunk את נתניהו . שותפיו לקואליציה גם xxunk שהדבר נועד לחזק אותו לקראת דיוני התקציב , שבהם , כדרכם של שרי אוצר , הוא מוצא את עצמו עם מעט כסף והרבה התחייבויות . עם מישהו xxunk " אני הולך " כדרכם של xxunk xxunk , לא מתעסקים . גם מצידו של לפיד xxunk ענן xxunk , על כך שהוא גמר אומר לא לשבת יותר באופוזיציה . המסר ברור : בכל מקרה תקום אחרי הבחירות הקרובות ממשלת לפיד - ליכוד , או ליכוד - לפיד . כדאי לך , כחלון , לחבור אלינו פן תקבל לכל היותר את תיק איכות הסביבה . כחלון , בניגוד למה שרבים חושבים , מעוניין יום אחד להיות ראש ממשלת ישראל . הוא לא יסכים לחבור ללפיד בלי רוטציה ( שאיננה מקובלת כלל על יו"ר יש עתיד , גם לאור ניסיון העבר העגום עם לבני והרצוג וגם לאור הסקרים ) . אפילו אם תהיה לו כזו , גט xxunk לימין אינו דבר של מה בכך למי xxunk בליכוד ותמיד xxunk לשמור עם אנשיו על קשרים טובים .
#   לשכת היועץ המשפטי לממשלה היא אחד המקומות xxunk במדינה . במשך חודשים ארוכים עסקה כל התקשורת הישראלית xxunk פרועים במה עוסקים תיקי נתניהו , אבל אפילו רמז קלוש xxunk מוזס או xxunk מילצ'ן לא דלף מכיוון המעגל הפנימי של מנדלבליט . אפשר להניח , לפיכך , שעם תום פסטיבל ההמלצות xxunk דממה ממושכת בכל הנוגע לחקירות 1000 ו-2000 . זה אחד המסרים xxunk נתניהו לכחלון , במישרין אבל בעיקר בעקיפין : אם תישאר בממשלה xxunk xxunk קרה ( או בעצם אש xxunk ) מהתקשורת , אבל כעבור כמה ימים סדר היום יתחלף xxunk לחזור לנושאים xxunk xxunk בשנה וחצי הקרובות .
#   הסיפור הגדול של השבועות האחרונים הוא xxunk למעשה של סיעת כולנו . השר יואב גלנט מנהל מסע פריימריז לכל דבר בליכוד , השר אלי כהן פועל באותו אופן xxunk במסרונים עם מנכ"ל המשרד של כחלון , xxunk אורן משמש כדובר של נתניהו לתקשורת xxunk . באותו xxunk שלושה חברי כנסת מכולנו מגיעים xxunk נגד נתניהו , ושתיים מהן , רחל עזריה ומרב בן ארי xxunk את המשמעת הקואליציונית בלי xxunk לקבל אישור מכחלון . אלי אללוף , xxunk בכנסת ממורמר xxunk , ביצע השבוע עבירה xxunk דינה הוא מוות פוליטי xxunk תמיכה באבי גבאי לראשות הממשלה . כולנו איננה מפלגה של איש אחד , אלא אוסף של עשר סיעות יחיד . אדם שמפלגתו מתפרקת לו בין הידיים עשוי להחליט שעדיף לו להישאר בקואליציה כי כלום לא מחכה לו בחוץ , או לחלופין לשלוח את כולם הביתה xxunk לעצמו סיעה צייתנית יותר . " xxunk לא תהיו פה " , הזהיר את חברי סיעתו השבוע xxunk מהם xxunk xxunk ברשת , ולא ברור אם זה היה איום או הבעת תקווה .
#
#   צעד xxunk לאחור
#   xxunk מלווה xxunk xxunk את xxunk השבוע על חוק ההמלצות . xxunk זמן הייתה פעם משמעות כאשר xxunk של חוק xxunk xxunk xxunk זמן הייתה xxunk את xxunk . הסיבה נעלמה זה מכבר , אבל הטקס xxunk כאן . זו לא xxunk של האופוזיציה , שאין לה שום כלי לנצח הצבעות ; זו xxunk של הכנסת , שלא xxunk להתחדש .
#   בזה אחר זה xxunk הכלים הפרלמנטריים של המאה ה-20 , מתים אך מוסיפים ללכת . הצעות האי אמון , xxunk אלפי ימי שני במרוצת השנים , xxunk לפעם בחודש לאחר שהתברר סופית שאין טעם לבזבז זמן יקר על אירוע xxunk ממשלה רק פעם אחת , לפני כמעט שלושים שנה . הצעות לסדר גם הן אירוע xxunk זמנו בעידן שבו עד שהן xxunk סדר היום הלאומי כבר xxunk שלוש פעמים . גם מהומת xxunk של ח"כ אילן גילאון עם השר החולה דוד אזולאי מלפני שבועיים נראית מיותרת לגמרי . לא כי סיוע לחבר xxunk הוא דבר רע , אלא כי עצם הדרישה להגיע להצבעה נראית קצת xxunk בעולם שבו כבר אין xxunk xxunk . למה בממשלה אפשר xxunk הצבעה ובכנסת לא ? האם ארבעים אלף בוחריו של חבר כנסת צריכים להפסיד רק כי נתקע xxunk או xxunk לשבוע ?
#   שלל המוסדות הפרלמנטריים האלה נראים xxunk מיושנת של xxunk סגור עם כללים xxunk , משהו כמו כינוס של ותיקי xxunk xxunk . מילא הכלים , אבל מה עם xxunk ? כדאי לזכור xxunk עד המחאה החברתית גם הכניסה בשערי הכנסת הייתה xxunk xxunk די הומוגנית של גברים אשכנזים בגיל העמידה פלוס , רצוי עם תואר עורך דין או דרגות במיל ' על הכתפיים . אוהבים להזדעזע מחברי כנסת כמו אורן חזן , או בזמנו שרון גל , xxunk xxunk פרלמנטרית " שבה הם נוהגים , אבל האמת היא xxunk לא xxunk . לא במקרה המנהיגים xxunk xxunk לעולם הם מעין פוליטיקה ללא פוליטיקאים , כמו סבון ללא סבון או קפה בלי xxunk . xxunk נבחר בן 39 xxunk עם xxunk xxunk xxunk בן 31 , בבריטניה עומד להפוך לראש ממשלה xxunk xxunk עם עמדות בלתי xxunk xxunk יושב בבית הלבן דונלד טראמפ . רוח התקופה היא עייפות xxunk על xxunk xxunk xxunk . בטח xxunk הזו נמשכת על פני שני לילות ללא שינה , עם xxunk xxunk xxunk xxunk .
#   רוחות חורף xxunk xxunk לאחרונה בין לשכת היועץ המשפטי לממשלה xxunk של מפכ"ל המשטרה . אתמול ניתנה לכך עדות נדירה . בבוקר פרסם " ידיעות אחרונות " מידע מעניין שממנו עלה חשד שעד המדינה מיקי גנור ניסה xxunk את שר האנרגיה יובל שטייניץ באמצעות xxunk xxunk בפריימריז . גורמים במשטרה xxunk בידיעה העריכו כי " לא יהיה מנוס xxunk את השר לחקירה באזהרה " .
#   מנדלבליט רתח . " לא חל כל שינוי בעניינו של השר " , מסר דובר משרד המשפטים , ואז הוסיף רמז עבה xxunk חקירה : " בכל מקרה , ההחלטה תהיה של היועץ המשפטי לממשלה , ולא של המפכ"ל " .
#   xxunk לעברית : בלשכת היועץ סבורים xxunk אלשיך ואנשיו מעוניינים להפעיל על מנדלבליט לחצים פסולים באמצעות הדלפות כדי להביא לחקירתו של השר . היועץ xxunk גבה xxunk בישר לפני שנה על xxunk הקרב של החקירה . הוא xxunk מאוד לפני שבועיים xxunk נעמד על xxunk xxunk – בניגוד לעמדת הפרקליטות – לחקור את יו"ר הקואליציה דוד ביטן דווקא בעיתוי הנפיץ של יום לפני ההצבעה המתוכננת על חוק ההמלצות . כשקרא בעיתון על שטייניץ , זה כבר היה יותר מדי .
#   הכול בסוף xxunk לנתניהו : היועץ המשפטי לממשלה מודע עד כאב xxunk xxunk xxunk לפתחו בחודשיים הקרובים . אוי לו xxunk תיק המתנות xxunk לו אם יעמיד לדין . הוא מבין עד כמה גבולי התיק מבחינה משפטית ועד כמה , מאידך , xxunk תהיה בעייתית מבחינה ציבורית . הדבר האחרון שהוא רוצה זה אוסף הדלפות מכוון שנועד לכלוא אותו אל מסלול xxunk של העמדה לדין . ויש עוד משהו : מפכ"ל המשטרה השתכנע עד תום xxunk xxunk של ניצב רוני ריטמן , שלפיה הוא הסתבך בפרשת xxunk מינית בגלל חוקרים פרטיים xxunk אליו גורמים xxunk בסביבת ראש הממשלה . ריטמן אמר זאת במפורש בעדותו xxunk , אלשיך מספר זאת בשיחות סגורות החל מיוני אשתקד ועד עצם היום הזה .
#   אלה דברים xxunk . אם המפכ"ל סבור xxunk לנתניהו שכרו חוקרים פרטיים על שוטרים , זה אירוע xxunk xxunk xxunk לידו , לא כל שכן תיקי 1000 ו-2000 . אז איפה החקירה הפלילית בפרשה ? ואם לא , xxunk זה מדאיג xxunk המשטרה xxunk xxunk תיאוריות קונספירציה סטייל הפגנות פתח - תקווה ? בכירים במשטרה xxunk על כך xxunk שהיועץ המשפטי לממשלה לא אישר או לא היה מאשר חקירה כזו . בפרקליטות , כמובן , משוכנעים שמדובר xxunk xxunk . היועץ המשפטי לממשלה נלחם ציבורית כדי שהמשטרה תוכל להמשיך למסור לו את xxunk , אבל נראה שגם הוא מתקרב לשלב שבו מתחשק לו לספק למשטרה המלצה להרגיע בדחיפות .
#   הימין החדש
#   שנה וחצי אחרי פרוץ חקירות נתניהו , הרוב המכריע של מחנה הימין עדיין עומד מאחורי ראש הממשלה . הגוש xxunk מעט אבל אחוזי התמיכה בנתניהו xxunk , בגדול , xxunk .
#   למעט חריג אחד : בניגוד למה שאפשר היה אולי לחשוב , הביקורת על ראש הממשלה לא מגיעות ממה שנהוג לכנות " הימין הרך " , אלא xxunk המחנה , הציבור הדתי לאומי . שלושים משלושים חברי הכנסת של הליכוד הולכים עם ראש הממשלה , סיעת כולנו שומרת על הקואליציה שלו , אבל בזה אחר זה xxunk עיתונאים ואנשי ציבור מהאגף האידיאולוגי של ההתיישבות ( קלמן ליבסקינד , נדב xxunk , ישראל הראל , הרב יובל xxunk ) נגד התנהלות נתניהו . הדיון הער xxunk בשאלה אם זו קריאה לטוהר המחנה או xxunk , הבעת אומץ לב או xxunk מה xxunk סוער .
#   הדיון המעניין יותר הוא השאלה אם xxunk כאן שני xxunk ימין . רגע אחרי xxunk בוש ירדה xxunk ההיסטוריה , המפלגה הרפובליקנית השתנתה לעד . מסיבת התה xxunk דור אחד של הממסד , וטראמפ – את מה שנשאר . הימין האמריקני החדש אינו צמוד xxunk xxunk xxunk של הימין הישן . הוא xxunk על מי xxunk לו את המדינה , xxunk חלק xxunk יושבים גם באגף xxunk . מי xxunk סקרים xxunk לראות כמה xxunk הליכוד אינם רואים עצמם xxunk לסדר יום שמרני מבחינה דתית , וימני מבחינה מדינית .
#   האם אחרי עידן נתניהו זה מה שיקרה גם פה ? והאם הציונות הדתית היא הממסד הישן xxunk בידי מסיבת התה הישראלית ? אירועי השבוע האחרון מעוררים את התחושה xxunk הגדול בימין ממתין אחר הדלת . באופן מוזר , מי xxunk שלטונו מעכב את xxunk הימין לרסיסים הוא דווקא נתניהו , שעומד בלב ההתכתשות .
#   עוד טרם xxunk האורות xxunk אל xxunk שלשום כבר xxunk xxunk הקשר שלפיה נאומו של נשיא ארצות הברית טראמפ נועד לחלץ את ראש הממשלה נתניהו xxunk הפליליות . מילא האמירה שלישראל אין מדיניות חוץ , רק מדיניות פנים . האם גם לאמריקה יש רק מדיניות פנים - ישראלית ?
#   נאומו המכונן של טראמפ נולד בשדות xxunk האמריקני , זה xxunk בערים xxunk xxunk עם שמות xxunk ( כולל חמישים xxunk ) . xxunk לבית הלבן היה סגן הנשיא מייק xxunk , אולי האדם xxunk ישראלי ביותר xxunk אי פעם בבית הלבן . הבסיס xxunk של בוחרי טראמפ רצה בצעד הזה , ומי xxunk עוד כהונה לא xxunk xxunk אותם .
#   יועצו לשעבר של נתניהו , רן xxunk , הסביר היטב בפוסט xxunk בפייסבוק מדוע נאום על ירושלים הוא סמל בלתי נחוץ , בטח בהשוואה למה שאנחנו באמת רוצים xxunk : סיוע אקטיבי xxunk איראן , xxunk האיום הגרעיני , פגיעה בחיזבאללה xxunk כלכליות דרמטיות .
#   xxunk הכמעט מוחלטת של נתניהו מעלה את השאלה אם היא xxunk xxunk דוברו לשעבר , או החלטה xxunk לפעול בכל הכוח מאחורי הקלעים . xxunk , נתניהו מאמין גדול במילים xxunk xxunk . הוא מאמין , בניגוד xxunk xxunk , xxunk לא נקבע בידי xxunk xxunk אלא בהסכמים xxunk .
#   אבל מאידך , xxunk הקודמים מאז בחירת טראמפ נראה היה שנתניהו לא פעל במיוחד למען המהלך . xxunk שורר , נציג המפלגה הרפובליקנית בישראל , הדהים לפני כשנה xxunk xxunk השגרירות לירושלים נמנעה בגלל בקשה מירושלים . נתניהו עצמו סיפר השבוע לחברי ועדת החוץ והביטחון xxunk כזו עשויה להוביל להסלמה בטחונית , לא בדיוק פיזור xxunk על xxunk של xxunk ישראל .
#   ומאידך , לשכת ראש הממשלה הייתה xxunk בכל פרט xxunk הנאום בבית הלבן . אפילו שעת השידור , שמונה בערב שעון ישראל , לא xxunk xxunk .
#   אפשר להניח שזה מה שקרה : טראמפ החליט כבר xxunk הראשון לעמוד xxunk הבחירות שלו כדי לבדל עצמו xxunk קודמים xxunk את הבייס שלו ; הוא תכנן לעשות זאת כבר בינואר אבל קיבל xxunk מהערבים שזה צעד בעייתי , xxunk – שיש דברים xxunk יותר . בחודש האחרון , xxunk החליט ללכת על מהלך רטורי עם xxunk של xxunk לפעולה מעשית , נתניהו ויד xxunk xxunk , רון דרמר , xxunk את xxunk , העיתוי xxunk של ההצהרה הדרמטית . הם לבטח לא xxunk על כך . הצהרת ירושלים xxunk המסתמן גם של שגרירות xxunk נראות כהישג דרמטי לראש הממשלה בשבוע שבו הוא xxunk למשהו אחר חוץ xxunk xxunk .
#   השאלה העיקרית היא אם xxunk תמורה ישראלית . מקורות xxunk השומרון xxunk הקפיטול כאחד xxunk לאחרונה , מי בחשש ומי בתקווה , על צעדים ישראליים דרמטיים בנושא הפלסטיני . ההיגיון הפוליטי אומר xxunk קושנר לא דיבר סתם בפורום xxunk לפני שבוע על פתרון הסכסוך xxunk לפיוס במזרח התיכון . xxunk xxunk – שעל xxunk בירושלים יידרש תשלום במטבע קשה .
#   ובכל זאת , ספק גדול אם כך יקרה . תומכי טראמפ לא ייראו בעין יפה לחץ אמריקני xxunk . הפלסטינים לא רואים בעיניים אחרי xxunk הציונית xxunk מהנשיא . ואילו מה שנתניהו מוכן לשלם לא xxunk ולא xxunk את מה שמוכן אבו מאזן לקחת . צעדים טקטיים אולי , מהלך אסטרטגי של ויתורים נראה כמעט דמיוני .
#   xxunk גבאי
#   שני אנשים xxunk xxunk נפגשו ביום שני האחרון לשיחה ממושכת . האחד איבד דקה קודם את יד xxunk הפוליטית ואת החוק שנועד להגן עליו , השני איבד בסוף השבוע xxunk אמינות וגם שישים אלף מצביעים , לפי הסקרים . בנימין נתניהו ומשה כחלון התכנסו כדי לברר אם יש עתיד לקשר שלהם .
#   xxunk בתקופה האחרונה חושפות שבניגוד מוחלט xxunk xxunk , הם אינם רוצים בבחירות . נתניהו xxunk שאיננו חושש xxunk אבל במשבר השבת עשה שעות נוספות כדי לשמור על הקואליציה . כחלון משדר לכולם כבר שלוש שנים שהוא ישן xxunk בממשלה , אבל בכל פעם xxunk כלפיו איום בחירות הוא xxunk לימין הליכוד . xxunk , לפיכך , הוא ששניהם xxunk בצוותא את תקציב 2019 , שאמור לעלות לממשלה בעוד חמישה שבועות , מהלך שיאפשר לכנסת הזו למלא את ימיה .
#   אבל זה לא כל כך פשוט .
#   חושב לעצמו נתניהו : כחלון קרס זה עתה תחת xxunk של הפגנה אחת בתל - אביב xxunk את תמיכתו בחוק ההמלצות . מי לידי יתקע שהוא לא xxunk באופן דומה אחרי xxunk המלצות המשטרה עצמן ? אולי במצב הזה עדיף כבר להקדים בחירות ולא להיגרר אליהן ?
#   חושב לעצמו כחלון : בפעם המי יודע כמה יוזמה הזויה של הליכוד גרמה לי נזק ציבורי כבד . מי לידי יתקע שלא תגיע עוד אחת , ועוד אחת ? אולי במצב הזה עדיף כבר ליזום בחירות ולא להיגרר אליהן אחרי xxunk את שארית xxunk במרכז ?
#   בפגישה ביניהם מפלס xxunk ירד . לא xxunk לתהליך של תקציב אם לא xxunk אותו , אמר שר האוצר . אני מעוניין בתקציב הזה , השיב ראש הממשלה . מי ששמע מה היה בפגישה התרשם שנתניהו מעוניין להרחיק את הבחירות ככל האפשר . תן לי זמן , אמר בניסוח כזה או אחר , שיח השחיתות xxunk חייב xxunk xxunk בסדר יום מדיני - בטחוני . xxunk לי יד , השיב כחלון במילותיו שלו . והוא הבהיר : אני דורש להפסיק מיד עם כל החוקים xxunk של הליכוד . xxunk האלה xxunk את ימי הקואליציה xxunk בעיקר בי . למחרת , כמחווה של רצון טוב , הוא הופיע בכנס כלכלי xxunk שמבחינתו " ראש הממשלה יתקשה להמשיך לאחר החלטת היועץ המשפטי לממשלה " – ובתרגום לעברית : אבל המלצת משטרה xxunk איננה עילה לפירוק הממשלה .
#   אבל רגע המבחן עוד xxunk . בעוד חודש או חודשיים , xxunk ההמלצות , יעמוד יו"ר כולנו בפני דילמה אכזרית : בוחריו , וגם חלק ניכר xxunk , ירצו בפירוק הממשלה . מכל סקר עולה xxunk אחוזים ממצביעי כולנו אינם אוהבים את נתניהו . המפלגה עצמה היא בעצם תנועת xxunk נתניהו . אם לא תעזוב את הממשלה , xxunk , יאמר לו האגף השמאלי במפלגתו . מאידך , כחלון זקוק לזמן נוסף כדי להביא הישגים כלכליים . אם תעזוב את הממשלה תקבל xxunk כפיים לחצי יום , ואז xxunk , xxunk אותו באגף הימני של כולנו . נתניהו מאמין שכחלון לא יעזוב . יש הבדל , חושבים בליכוד , בין בלימה xxunk של חוק xxunk לבין xxunk xxunk של הממשלה . מהלך כזה יהיה סוף דרכו בימין , כולל האפשרות xxunk להתמודד על ראשות הליכוד אחרי עידן נתניהו .
#   ההכרעה של כחלון תלויה גם xxunk xxunk : האם להתמודד שוב לבדו , אולי xxunk xxunk ? לחבור לליכוד ? או אולי דווקא ללפיד ? באפשרות האחרונה xxunk גם בונוס מיוחד , xxunk xxunk : האפשרות לחסל את שנוא נפשו אבי גבאי . עד לפני כמה שבועות זה נראה דמיוני . כחלון לא סובל את כל מה שלפיד מייצג ולפיד משוכנע שכחלון הוא שר אוצר לא אמיץ xxunk את הכסף שהוא xxunk xxunk רב . אבל הפוליטיקה כבר ראתה xxunk xxunk מאלה . חבירה עתידית ללפיד אחרי פירוק הממשלה על רקע שלטון החוק היא שובר שוויון של ממש . הרי בסקרים הנוכחיים כחלון כבר xxunk בתוך גוש הימין . בלעדיו , הימין ניצב בפני משימה כמעט בלתי אפשרית .
#   אחרי שנה של הפגנות xxunk בפתח תקווה , עצרת מוצ"ש האחרון בתל אביב xxunk בכחלון xxunk הייתה מהלך אופוזיציוני מרהיב . למחרת , xxunk xxunk ההפגנה את הטלפון של שר האוצר xxunk לשגר אליו xxunk שקוראים לו לצאת נגד נתניהו . xxunk של כחלון , הוא xxunk זה מכבר את הווטסאפ בטלפון הזה .
#   תם עידן ביטן ?
#   הביקורת החריפה על עיתוי חקירתו של יושב ראש הקואליציה xxunk במשטרה , אבל xxunk את מי שאישר אותה : על פי xxunk , היועץ המשפטי לממשלה הוא זה xxunk לחוקרים לזמן נבחר ציבור . למשטרה יש את xxunk שלה , חלקן נחשפו השבוע בדמות בכיר xxunk באופן הזוי על ההפגנה בתל אביב או xxunk בתיקי נתניהו xxunk בפייסבוק למען הצלחת xxunk . אבל מנדלבליט שונה : נתניהו , למשל , מקפיד מאוד בכבודו של היועץ . הוא xxunk לא לתקוף אותו , xxunk הידוע גם משוכנע xxunk יסגור את כל התיקים xxunk אליו המשטרה . ראוי גם להזכיר xxunk היועץ שמרה כמעט שנה xxunk מוחלט על xxunk של תיקי נתניהו , ללא xxunk אחת .
#   ולכן xxunk xxunk , אחראית xxunk xxunk xxunk לחקור את יושב ראש הקואליציה ובכך xxunk xxunk מוות על חוק ההמלצות , כנראה שיש לכך סיבה טובה . על פי ההדלפות xxunk החקירות , ביטן xxunk במצב משפטי נואש . חוקרי המשטרה xxunk אותו היטב xxunk את הקריירה הפוליטית שלו אל מה שנראה xxunk הבלתי נמנע . איזה עולם משונה : לפני חודש בלבד ביטן הבהיר שיקבל בקרוב תיק בממשלה מנתניהו , אבל בסוף חטף תיק פלילי xxunk .
#   גם xxunk xxunk - למדי בכנסת xxunk השבוע xxunk של ביטן החיוור xxunk במליאה בין חקירה לחקירה . יו"ר סיעת הליכוד הוא דמות אהובה במסדרונות הכנסת . איתו אפשר לגנוב סוסים ובלעדיו יהיה קשה יותר להעביר תקציב xxunk .
#   אבל בדיעבד , צמד החוקים שקידם ביטן בחודשים האחרונים נראה מטריד למדי : חוק ההמלצות וחוק ההקלטות . על פי הידוע , חלק ניכר xxunk המרשיע נגד יו"ר הקואליציה הושג בהקלטות , חלקן לפי השמועות בכנסת xxunk בידי דמות קרובה מאוד ( מאוד מאוד ) xxunk . בשלב מסוים הוא הסכים xxunk עיתונאים xxunk , אבל להותיר בו אזרחים xxunk . האם הוא חשב גם קצת על עצמו ?
#   xxunk נחקר בראשון xxunk אבל בשני xxunk מסתובב בכנסת כרגיל , האם זה אומר שהוא לא הבין xxunk השתנו , או xxunk לא מבינים xxunk השתנו ? האם הוא לא xxunk xxunk הציבורית שלו xxunk ברגע שנמצאו כנראה xxunk מיליונים לא xxunk ? או xxunk שבו פוליטיקאי xxunk חיש קל מרגע שהסתבך חלף ?
#   ההכרעה הקשה xxunk כעת לפתחו של ראש הממשלה . מתישהו הוא יצטרך להכריע אם להיפטר xxunk , בין אם כדי לקבל יו"ר קואליציה שלא xxunk מימי חקיקה לטובת ביקורים xxunk xxunk , ובין אם כדי לבדל את עצמו מפוליטיקאי xxunk עד צוואר . קל xxunk זה לא יהיה .
#   ביום ראשון , בשעת צהריים , xxunk הקואליציה לרגע xxunk ביותר שלה בשנה האחרונה . השר ליצמן הפקיד זה עתה את מכתב ההתפטרות שלו מהממשלה , xxunk את הליכוד ואת חבריו xxunk ויהדות התורה בניגוד עניינים חריף . מפלגת השלטון הייתה צריכה להוכיח xxunk שהיא איננה בכיס של החרדים , ואילו החרדים היו חייבים להוכיח xxunk שהם אינם בכיס של הליכוד .
#   ובאותו הרגע xxunk הכרעה על חוק המרכולים . האם להרגיע את הקואליציה xxunk את הבוחרים או xxunk את הקואליציה ולהרגיע את הבוחרים ?
#   ללשכת ראש הממשלה xxunk שניים xxunk xxunk של הליכוד , השרים יריב לוין xxunk אלקין . הם xxunk בפני נתניהו גישות xxunk לחלוטין .
#   לוין הציע לרכך , xxunk xxunk את חוק המרכולים . " אסור שניתן מתנה ללפיד " , הסביר לנתניהו וגם לדרעי . לא סתם גוש הימין מתכווץ : xxunk שבת הן xxunk הקולות מספר אחת של הימין . אישור חקיקה xxunk - חרדית xxunk ייתפס xxunk xxunk של הליכוד xxunk את יש עתיד . עדיף לחכות שבוע שבועיים , עד xxunk xxunk מסדר היום הציבורי . ואם , כמו שחשבו לא מעטים בקואליציה , פרישת ליצמן xxunk לשאר חבריו את הדרך , יהיה אסון להיכנע לחרדים ממש ערב בחירות .
#   אלקין חשב אחרת : הוא ראה שדרעי מחרים את ישיבת הממשלה במחאה על xxunk המסתמן בחוק המרכולים . גם ישיבת ראשי הקואליציה בוטלה באופן תקדימי . מי שלא מגיע לממשלה יכול גם להיעדר מהכנסת למחרת , והכל יכול לצאת משליטה . אם לא xxunk את זה כאן ועכשיו xxunk לבחירות . אם xxunk עם החרדים , אמר לנתניהו , נוכל להמשיך עוד שנתיים . xxunk קטטה זמנית עם הבוחרים על xxunk עם השותף הטבעי מספר אחת .
#   נתניהו , כידוע , בחר אלקין . הראיות לכך xxunk כבר בישיבת שרי הליכוד . השר אופיר אקוניס הציע לחבריו xxunk את המסר שהליכוד איננו בכיס של החרדים : " האדמו"ר מגור לא ינהל את המדינה " , אמר . נתניהו xxunk . " אני מציע xxunk הזו לא תצא xxunk " , אמר xxunk . " להיות מנהיג זה גם ללכת נגד הציבור שלך xxunk " . בינתיים , זה xxunk לו . משבר שנראה ערב שבת xxunk דרכה של הממשלה נעלם לחלוטין כבר ביום שני . הליכוד והחרדים הגיעו להסדר כולל , עד סוף הכהונה . לפי הפרשנות המקובלת בליכוד , גם xxunk של ישראל ביתנו למהלך xxunk עם נתניהו . חשוב שהחרדים לא ירגישו xxunk לגמרי , כפי שטוענים כמה פרשנים במגזר .
#   מחלוקת לוין - אלקין איננה טקטית אלא אסטרטגית . בתוך הליכוד xxunk שתי מפלגות . אחת , ליכוד חילוני , xxunk xxunk " , xxunk xxunk , לתל - אביב . זה הליכוד של אקוניס וחיים כץ וביטן וגם של נתניהו . הוא מרגיש לגמרי xxunk בקואליציה עם לפיד xxunk חקיקה ליברלית מבחינה אזרחית xxunk מבחינה כלכלית , דבר שלא xxunk בשותפות עם החרדים . ויש ליכוד מסורתי - דתי xxunk יותר xxunk עם xxunk xxunk גדולי התורה . לליכוד נשארו מעט מאוד מצביעים ימנים - חילונים , אבל הרבה מאוד חברי כנסת כאלה . למשל , בנימין נתניהו . ההחלטה האסטרטגית , לאיזה כיוון ללכת , תקבע איזה ליכוד יהיה כאן .
#   החלון של כחלון
#   באמריקה הייתה פעם xxunk xxunk xxunk התרבות : " התכנית הטובה ביותר שאתה לא צופה בה " . בהשאלה , כולנו היא המפלגה הטובה ביותר שאתה לא מצביע לה . על פי xxunk xxunk xxunk שנשפכו על משה כחלון xxunk xxunk אפשר היה לחשוב שמפלגתו קיבלה בבחירות האחרונות חמישים מנדטים על מצע של תמיכה xxunk xxunk xxunk , ולא עשרה מנדטים xxunk שרצו דירה קצת יותר xxunk . xxunk מזכירים את ההוא xxunk xxunk ועוד xxunk שלא קיבל עודף .
#   הסיבה שכחלון לא פירק את הקואליציה על חוק ההמלצות היא שהוא לא רוצה בשום פנים xxunk לפרק את הקואליציה . xxunk ביטן - אמסלם השמיע באוזני בכירי " כולנו " את איומי הבחירות אם היוזמה לא xxunk בכנסת , זה נכון שהסיכויים xxunk היו xxunk . אבל מי שנכווה במשבר התאגיד xxunk בחוק ההמלצות . אז זה היה , לפי הטענה , היועץ ליאור חורב שהציע לכחלון להתנגד לסגירת התאגיד כדי לצבור תמיכה במקומות הנכונים . שר האוצר התחרט מרה על xxunk על העץ הזה מרצונו החופשי , xxunk הנדל"ן טרם ירדו xxunk המיסים טרם xxunk . אין לו שום כוונה להסתכן xxunk על עץ חדש xxunk הליכודניקים xxunk את xxunk . ולכן , חוק ההמלצות יעבור . " אני שר המוסר , לא שר האוצר " , אמר .
#   בינתיים xxunk דברים xxunk xxunk התיקים . בשבוע שעבר נטען בכמה מקומות שנתניהו xxunk קשות xxunk השישי שלו עם חוקרי המשטרה . אבל השבוע התברר שהמצב אולי הפוך : בחדשות עשר פורסם שהחקירה הזו דווקא xxunk משמעותית את טענות השוחד כלפי ראש הממשלה בתיק המתנות , תיק אלף , וכעת נותרה המשטרה עם מרמה והפרת אמונים " בלבד " . ביום שלישי הודיעה דוברת המשטרה בכנס xxunk שלפי שעה יש קושי משפטי להוכיח עבירות על החוק בתיק השיחות עם נוני מוזס , תיק אלפיים . ובאותו יום הודיע פרקליט המדינה שי ניצן , חד וחלק , שראש הממשלה איננו חשוד בתיק הצוללות , תיק שלושת - אלפים .
#   נתניהו לא יכול לקוות xxunk טובות יותר . המלצה משטרתית xxunk , בתיק בודד , xxunk על מנדלבליט ציבורית לסגור גם את החקירה הזו , אם xxunk שיש קושי להשיג הרשעה . אם לא מדובר xxunk xxunk או xxunk xxunk , הוא צריך להיות מעודד .
#   אבל אם זה המצב , מה גורם לראש הממשלה xxunk את הכנסת בחוק ההמלצות ? הרי הוא האדם היחיד במערכת הפוליטית xxunk באמת מה ההאשמות xxunk בו בידי החוקרים . האם הוא התרשם שהמצב שלו חמור xxunk ולכן החליט xxunk את החוק xxunk ? או שמדובר xxunk ליכודית שיצאה משליטה ?
#   לוח הזמנים של החקירה מביא את ההכרעה הסופית אם להעמיד לדין את נתניהו בערך xxunk 2019 . אם לשימוע לשרה נתניהו xxunk ארבעה חודשים , בעלה xxunk יותר יקבל חצי שנה . אם הכרעה בתיק הקטן שלה xxunk כל כך הרבה זמן , החלטה דרמטית בהרבה על העמדה לדין של ראש ממשלה תיקח עוד יותר .
#   משמאל מאשימים את היועץ המשפטי לממשלה xxunk כדי להציל את נתניהו . אולי כדאי לחשוב על סיבה אחרת . מנדלבליט מבין שתיק אלף הוא תיק קשה משפטית , על הגבול xxunk , באיזור שבו אין הרשעה מובטחת ואין סגירת תיק קלה . העובדה שמדובר בראש ממשלה xxunk חומרי xxunk לתיק נפיץ גם כך . במבט מהצד , נראה שמנדלבליט היה מעדיף לקבל את ההכרעה הזו אחרי שנתניהו כבר איננו ראש הממשלה , xxunk הציבורי לא כה xxunk xxunk . ככל שההחלטה xxunk , גוברים הסיכויים שהממשלה הנוכחית תלך בדרך כל ארץ , בלי התערבות משפטית .
#   תחקיר : כך הקים השגריר באו"ם , במסווה של פעילות ציונית , מנגנון לחלוקת משכורות xxunk לעשרות פעילי ליכוד xxunk – בתמורה לתמיכה פוליטית . xxunk xxunk חושפות : המנגנון מכספי ציבור למען xxunk
#   תחקיר : לא סתם מגיעים מעמדה של כמעט xxunk בליכוד להיות ח"כ , סגן שר הביטחון , שר ועכשיו שגריר באו"ם . זה קורה עם הרבה מוטיבציה ובמקרה של דני דנון – גם הרבה כספי ציבור , כספים שלנו . בתחקיר ששודר הערב ( שני ) במהדורה המרכזית נחשפו הקלטות xxunk xxunk על המנגנון שהקים דני דנון לחלוקת משכורות xxunk לעשרות פעילי ליכוד מכספי ציבור בתמורה לתמיכה הפוליטית בו . כך הפך דנון הפך בתוך שנים xxunk ממי xxunk בקושי את טל xxunk בפריימריז – xxunk הליכוד . דנון בתגובה : " xxunk לא נפל רבב " .
#   צפו בתחקיר המלא
#   דנון עמד במשך שנים בראש הליכוד העולמי , תפקיד עם השפעה עצומה על מינויים xxunk במוסדות הלאומיים . במהלך הזמן הוא גילה עניין מיוחד בגוף קטן , המועצה הציונית , ובמיוחד בעמותה נשכחת שלה בשם " עושים ציונות " . לפני שש שנים דנון xxunk בראשה את מקורבו , יעקב xxunk . מה קרה מאז ? ב-2011 קק"ל , שגם בה יש לדנון השפעה רבה , נתנה xxunk אפס שקלים בדיוק . אך לפתע החלו xxunk xxunk אדירים , כולם כספי ציבור xxunk , xxunk xxunk " עושים ציונות " . ב-2012 כמעט שני מיליון שקלים , ב-2013 למעלה xxunk מיליון xxunk חמישה עשר מיליון שקלים .
#   מספר העובדים של xxunk , שעמד על שלושים בלבד , זינק לכמעט מאתיים – xxunk עובדים xxunk של כסף תמורת פוליטיקה . תחת הכותרת הציונית החשובה xxunk דנון xxunk בעמותה מערך עצום , בשכר , של פעילי ליכוד כדי xxunk לו ביום פקודה . באופן רשמי נקרא xxunk מיזם " xxunk " , xxunk ציונות ברחבי הארץ . בפועל , מדובר בתעשייה xxunk כבר שנים עד היום השלמת הכנסה של אלפי שקלים בחודש לעשרות פעילי ליכוד , ראשי סניפים , xxunk , xxunk . העסקה ברורה : תן תמיכה , קבל משרה בתור רכז xxunk .
#   " הם רוצים xxunk יסתדר , והוא נותן להם xxunk "
#   דנון העביר בקביעות xxunk הוראות xxunk – לאיזה ליכודניק לסדר הפעם ג'וב בשכר . xxunk שנמצאו xxunk המוסדות הלאומיים עם ההנחיות של דנון xxunk בין השאר את המשפטים " מעלה אדומים – לבקש שם xxunk אמסלם " , " חולון – אולי צריך נציג xxunk ? " xxunk גת – הבת של xxunk " – xxunk xxunk , בת של חבר מרכז xxunk גת . " איך xxunk ? אבא שלי הוא פעיל ליכוד והם מכירים אותו אז הם פנו אליי " , היא מספרת .
#   עוד הנחה xxunk : " xxunk – דני צריך לדבר עם ראש העיר , xxunk – לברר מי xxunk שנתן ראש העיר xxunk , ירושלים – xxunk xxunk נציג חרדים ( איש של xxunk ) , שדרות – לראות את מי נתן אלון xxunk ( ראש העיר ) " . והרשימה נמשכת : " שומרון – גרשון ( מסיקה ) הביא שני אנשים , גבעת שמואל – אפשר אולי דרך xxunk xxunk ? xxunk – דודי אליהו ( לבקש ממנו חוג בית ) , דימונה – xxunk ( הבת של ראש העיר בני ביטון ) " . xxunk ביטון , בתו של ראש עיריית דימונה , מספרת : " זה לא הרבה עבודה , זה פעם בשבוע " .
#   " אתה מצופה לעזור למערכת "
#   גם xxunk ביקש דנון את מושיק xxunk " ( הבן של חיים , יושב ראש xxunk ) " , שטוען כי אין קשר בין xxunk – בערך שעתיים עבודה בחודש – לבין היותו הבן של יו"ר xxunk . למי xxunk , לרוב לא מדובר בעבודה קשה מדי למען הציונות : מ ' , חבר ליכוד xxunk , מודה כי " יש חודשים שאת עושה כסף xxunk על הדרך . בגדול כמעט לא עשיתי כלום , סתם עשיתי העתק הדבק על כל דבר שעשיתי xxunk את הכסף " . xxunk הזו xxunk משכורות במשך שנים ליותר ממאה פעילי ליכוד ובני משפחותיהם . אך לא מדובר במתן בסתר – מתישהו דני דנון רוצה תמורה .
#   שמעון xxunk , חבר מרכז ליכוד xxunk , סיפר : " ברובם זה xxunk שיש להם קרבה מסוימת לדני xxunk את דני , xxunk xxunk יסתדר . והוא נותן להם xxunk , אלה בדרך כלל חברי מרכז או חברי סניפים או יש איזה בן xxunk xxunk . הוא ( דני ) נותן להם את זה xxunk xxunk לו בהמשך " . דנון ואנשיו במועצה הציונית רוצים xxunk עבודה פוליטית בבחירות בליכוד .
#   דור xxunk , חבר מרכז ליכוד xxunk , הסביר איך עובדת השיטה : " אני xxunk סיוע xxunk אחרים , חתימות , לחץ על חברי מזכירות , סיוע במרכז xxunk במרכז . היה אז האירוע של ליברמן שרצו לא לאפשר את זה xxunk יילכו ביחד , אז xxunk 300 - xxunk חתימות … אתה מצופה לעזור למערכת . להביא את החברים שלך להכיר אותם לדני " . רותם אוחנה , יו"ר סניף הליכוד xxunk , אמר : " עליי היה נופל הכל כי אני גם הייתי עושה מצד אחד את הפעילות ומצד שני הייתי גם xxunk להם ( לדני דנון ) אם יש בחירות " .
#   דנון תמיד רץ לתפקיד כלשהו : לראשות הליכוד או לפריימריז , לראשות המרכז או xxunk . הפעילים נדרשים לספק תמיכה : ראובן xxunk , xxunk בכיר בליכוד , השיב לשאלת החדשות האם התפקיד xxunk xxunk לדני " ואמר : " המועצה הציונית מנסה להיות נמנעת , אבל בזמן הבחירות אנחנו xxunk אנשי ליכוד בעיקר לדני דנון " . xxunk דנון שנמצאו xxunk מעידים על xxunk ממנכ"ל המועצה הציונית לארגן xxunk בית xxunk xxunk , רכז הציונות xxunk xxunk אזולאי קיבל הנחיה xxunk חברי מרכז על מועמדותו של דנון לראשות הליכוד ובאופן דומה השיג אורן כהן , רכז ציונות בכפר סבא וראש סניף הליכוד בעיר , חתימות .
#   חלק xxunk מקבלים הבטחות xxunk שווה יותר , xxunk גם xxunk – כך למשל xxunk לענייני xxunk במועצה הציונית , xxunk רזיאל . " אני שלוש קדנציות עשיתי איתו בפריימריז , אני אחראי על מעל אלף חברי ליכוד " , אמר רזיאל . " ב-2014 , מתי שהוא עשה מלחמה ( בפריימריז ) הם אומרים ' בשביל דני , אם אתה עושה עוד xxunk חברי ליכוד חדשים אנחנו xxunk לך ( מינוי כראש ) מחלקת מדינות xxunk xxunk xxunk xxunk לך ארבעה xxunk ( בתשלום ) ' . xxunk " .
#   לצד xxunk " , יש גם xxunk : פעילי ליכוד מעידים על מקרים שבהם מי שלא xxunk תוצאות פוליטיות או מעז לתמוך במועמד אחר xxunk מתפקידו . חבר המרכז דודי אליהו xxunk במשרה של xxunk שקל בחודש – אבל שכרו xxunk דרמטית : " אני עדיין עובד שם xxunk בתפקיד הרבה יותר קטן . הסיבה xxunk הייתה xxunk xxunk xxunk ? בגלל xxunk הפוליטי כנראה לא היה מספיק xxunk " .
#   בסיוע המנגנון דנון xxunk xxunk : xxunk הרשימה ב-2009 ( מקום 25 ) xxunk xxunk ב-2013 , ובבחירות האחרונות – היישר לממשלה . " אני חבר טוב של דני דנון , כל הזמן הייתי חייל שלו " , מספר xxunk רזיאל , הפעיל xxunk למען דנון . " xxunk ציונית , xxunk ציונית , אפשר להגיד שהוא בעל של הארגונים האלה " . לדבריו , גם xxunk באו"ם הוא מעורב באותם ארגונים .
#   דנון : " אופן הצגת השאלות מוכיח על עריכה xxunk xxunk להוציא דיבה "
#   לכאורה , דני דנון איננו פוליטיקאי עכשיו אלא xxunk . בפועל , המערך xxunk xxunk בשם הציונות ממשיך לפעול . עוד קודם לכן , xxunk דנון עומד בפני מבחן פוליטי , עמותת עושים ציונות xxunk מכספי ציבור הופכת למטה בחירות לכל דבר xxunk , שקרוי על ידי דנון " צוות xxunk " . ביולי 2013 נערכה במרכז הליכוד הצבעה חשובה לדנון , וכל בכירי xxunk עזבו את הפעילות הציונית כדי להפוך xxunk של דנון . אייל אטיאס שלח לחבריו בעמותה מייל בזו הלשון : " שלום חברים , יש לעשות טלפונים למחר . יש xxunk לפי xxunk . תגידו להם ' לכו להצביע ' . בהצלחה בשם האומות xxunk , תל חי " .
#   שנה אחר כך דנון xxunk מתפקידו כסגן שר הביטחון , והוא xxunk כינוס מרכז xxunk , ממש באותו ערב שבו xxunk דאז נתניהו קיים xxunk כוסית . מדובר xxunk כוח מכריע לדנון , xxunk הציונית שוב xxunk כולה : " כרגיל " , כותב יועץ דנון , " כל אחד יקבל xxunk שיחות אישית xxunk . xxunk תסריט השיחה – נעשו כמה נסיונות xxunk תאריך עם ראש הממשלה – אך כל הניסיונות נכשלו " .
#   xxunk זייטמן הוא היועץ האסטרטגי של דני דנון . הפלא ופלא , אותו זייטמן הוא גם היועץ האסטרטגי של עמותת עושים ציונות . בשנתיים בלבד הוא קיבל ממנה חצי מיליון שקל . האם מדובר בצירוף מקרים בלבד ? והנה צירוף מקרים דומה : משרד הפרסום גל אורן הולך שנים עם דני דנון , הוא xxunk לו את xxunk הגדולים xxunk שהוא ידוע בהם , xxunk את xxunk בפריימריז על ראשות הליכוד של 2014 . הפלא ופלא , גל אורן הוא גם משרד הפרסום xxunk האסטרטגי של עמותת עושים ציונות . ב-2013 xxunk אלף שקלים , xxunk , שנת הפריימריז בליכוד , xxunk מזנק לכמעט שני מיליון שקלים .
#   על מה הלך הכסף ? שאלה טובה . דוח טרי טרי של מבקר הפנים קבע : " נמצא xxunk xxunk מספר xxunk המשך עם חברת גל אורן לטובת xxunk אירועים xxunk של מאות אלפי שקלים , ללא קבלת הצעות מחיר נוספות וללא תיעוד הנסיבות . הדבר אינו xxunk " . בקיץ הקרוב ישוב דנון מתפקידו xxunk לארץ . בארץ ימתינו לו עשרות פעילים xxunk תודה עם השלמת הכנסה xxunk להם xxunk אחת שאמורה לעשות xxunk אבל במקביל עושה גם פוליטיקה במיליונים – בניגוד לחוק , והכל כמובן על xxunk .
#   פנינו כבר לפני ארבעה ימים לדני דנון כדי לבקש את תגובתו xxunk וגם xxunk את xxunk ביממה , לבקשתו . הערב בחר דנון למסור את התגובה הבאה : " לצערנו הרב xxunk להתעלם xxunk בלי להותיר זמן ראוי להגשת תגובה שהייתה xxunk את הטענות xxunk xxunk לא נפל רבב . אופן הצגת השאלות מוכיח על עריכה xxunk xxunk להוציא דיבה . אני פועל כבר למעלה מעשרים שנה בחזית ההסברה וביתר שאת xxunk באו"ם . מחר משלחת ישראל xxunk xxunk שבעים שנה xxunk בנובמבר באירוע היסטורי בניו יורק " .
#   xxunk הציונית נמסר : " הטענות בכתבה xxunk xxunk שחר . אנשי המועצה ממלאים את xxunk על בסיס ערכי הציונות , אהבת הארץ xxunk למדינה . אין חולק על כך כי בשנים האחרונות המועצה מובילה xxunk xxunk אדירה xxunk על כך להערכה מכל xxunk הפוליטית . הכתבה xxunk מכל המוסדות אשר בראשם עומדים נציגי תנועת העבודה , מרצ , הבית היהודי ועוד . הימים בהם נדרש xxunk אדום להיות חבר במוסדות הלאומיים חלפו מהעולם . במועצה עובדים בעלי השקפות פוליטיות שונות משמאל ומימין " .
#   xxunk זייטמן xxunk עבור המועצה הציונית עבודה מקצועית רבה , שבמסגרתה xxunk תשתית לפעולות ציוניות xxunk ועל זה קיבלתי את כספי . לא קיבלתי אפילו xxunk אחת שאינה מגיעה לי כדין " .
#   xxunk גל אורן xxunk קשר בין הפעילות בפריימריז של דני דנון לבין xxunk אחרים שאנחנו xxunk להעניק xxunk לקוחות , ובהם גם xxunk xxunk של המועצה הציונית " .
#   אתמול בבוקר מלאו xxunk הרדיו בפוליטיקאים חרדים xxunk xxunk על xxunk השבת ברכבת . היה בזה משהו קצת משונה . הרי קול ישראל xxunk צה"ל הם גוף ממשלתי xxunk צבאית xxunk בשבת במתכונת מלאה , ואיש אינו xxunk פה או מפרסם xxunk . למה על עבודות xxunk מוכנים לפרק קואליציה ועל האות של החדשות לא ?
#   כי הסיפור איננו השבת , או הרכבת , אלא דווקא המשטרה . מדי שבת בשבתו xxunk עבודות xxunk ברכבת , כמעט תמיד בהשתתפות יהודים . הרכבת מבקשת , שר העבודה מאשר , המשטרה xxunk את העבודות . הבעיה מבחינת החרדים היא xxunk התנועה של המשטרה נוהג להפיץ בווטסאפ אילו xxunk xxunk בשל xxunk xxunk . xxunk החרדיים הפכו את ההודעה xxunk הזו , ובצדק מבחינתם , לסחורה xxunk xxunk . כל כך xxunk , שהיא החלה xxunk השבוע את כסאו של שר הבריאות .
#   במשך שעות , xxunk ועד כמעט כניסת השבת , עוסקת צמרת המדינה xxunk טקטיקה . הרכבת מוכנה רק xxunk העבודות , אבל ליצמן כבל עצמו xxunk ציבורית : אפילו לא עובד אחד .
#   דרעי וגפני ניסו לדבר על ליבו , בהתחלה ישירות ואחר כך דרך ציטוטים xxunk . xxunk עליו שבת אחת כדי שישמור xxunk הרבה , אמרו לו . ובעברית : אפשר לסבול עבודות xxunk xxunk בשבועות הקרובים אבל להישאר בממשלה ולהעביר את חוק המרכולים , חוק שעות העבודה xxunk וכמובן – חוק גיוס נוח .
#   ליצמן מאוד לא רצה לעזוב את הממשלה , או יותר נכון : מאוד מאוד לא רצה . אבל היו לו דרכים xxunk לומר את זה . הנציגים החרדיים האחרים xxunk להתיישר מאחוריו xxunk שיניים . הבעיה של נתניהו היא הביצה xxunk xxunk השבת . בוחריו ימניים אבל לא סובלים כפייה דתית . עוד פחות מזה הם סובלים xxunk . גם כך xxunk התחבורה של ישראל הולכים xxunk . אם הם xxunk , נתניהו יוכל לראות xxunk עד מחר . בוחריו ייראו xxunk xxunk xxunk . פתרון למשבר השבת הנוכחי עוד היה אמור להיות דבר קל יחסית . זה הטקס הקבוע של משבר קואליציוני xxunk השני של השבוע שהוא חייב למגר , xxunk בהקדם .
#   דור הולך xxunk בא
#   זה היה מפגש xxunk , בין xxunk , במליאת הכנסת . בישיבה , בני בגין , בעשור השמיני xxunk . xxunk בן xxunk , ליברל בן ליברל , לא נבחר בליכוד כבר קרוב לעשור . xxunk , מימינו xxunk , דוד ביטן ודוד אמסלם . xxunk משטרה xxunk , xxunk ראשונה xxunk בפריימריז הקרובים . הוא xxunk , ונראה היה xxunk xxunk עליו . הם דיברו בלהט , עם הידיים , עד xxunk xxunk למקום . כשזה לא עזר לשכנע אותו להתיישר עם xxunk חוק ההמלצות על חקירות נתניהו , החליטו לסלק אותו מועדת הפנים .
#   זו הקדנציה האחרונה של בגין , אמסלם וביטן xxunk כנסת . הראשון xxunk בתום הכהונה . במילותיו שלו מלפני עשרים שנה , הוא שליח ציבור בלי ציבור . השני והשלישי ירצו להתמנות לשרים בממשלת נתניהו החמישית , אם תקום .
#   בגין מצוי xxunk סופי , מוחלט , עם נתניהו . בכל זאת תקף לא פעם בחודשים האחרונים את הקריאות לראש הממשלה להתפטר , השתלח xxunk פתח תקווה xxunk תמיכה xxunk המרכז למען נתניהו . בעניין חוק ההמלצות הוא סירב להתיישר . השר לשעבר הציע שהחוק יחול רק בעוד כמה חודשים , כדי למנוע מירוץ משפיל בין הכנסת לממשלה , בין השלמת החקיקה xxunk החקירה .
#   אתם כל הזמן טוענים xxunk xxunk כדי לחלץ את נתניהו , אמרתי לדוד ביטן שלשום בערב , אבל הנה יצא xxunk xxunk . סילוקו של בגין מוכיח שמטרת העל איננה xxunk במשטרה אלא xxunk המשטרה בתיקי אלף ואלפיים . קודם כל , השיב ביטן xxunk הצידה xxunk באירוע של פעיל ליכוד , לא אמרתי אף פעם שחוק ההמלצות לא xxunk בנתניהו . את זה xxunk רק על החוק הצרפתי . שנית , אם יש בעיה נגד חקיקה xxunk צריכה להיות גם בעיה נגד אי - חקיקה xxunk . בגין רוצה שהחוק יחול על כולם חוץ מאשר על ביבי . חוץ מזה , אמר xxunk , גם בגין הוא חבר קואליציה , וגם הוא כפוף למשמעת . אני אוהב אותו ואת אביו , xxunk על כבודו גם כשלא הצביע איתנו , אבל כאן לא נותרה ברירה .
#   יכול להיות . הרושם שנוצר , גם xxunk של פרקליטו הטרי של נתניהו , xxunk חן , בעד חוק ההמלצות , הוא שמדובר במהלך xxunk מלמעלה . הרי מסרון אחד היה מספיק כדי לבלום את יוזמות החקיקה . מה שלא יעשה xxunk תעשה כנראה הקואליציה : השרים איילת שקד וגלעד ארדן כבר xxunk את רוב החוק מתוכן , בלי עונש מאסר xxunk ובלי xxunk לפתוח בחקירה משטרתית xxunk ; חברי כולנו ראו את בגין xxunk חיזוק ציבורי xxunk נגד החוק . גם אחרי xxunk בגין , נכון xxunk בבוקר , xxunk ואמסלם עדיין חסרים שני קולות .
#   הולך ודל
#   xxunk של בגין אל הקרח לא אמורה להיות אירוע משמעותי xxunk . זה הרי כבר קרה פעמיים בעבר בלי xxunk המנדטים xxunk . אבל xxunk xxunk מאבד הימין כוחות משמעותיים . בתוך שנה וחצי xxunk מהמחנה משה יעלון ( לאומי ליברלי ) , אורלי לוי ( לאומי - חברתי ) , אבי גבאי ( ימין כלכלי ) xxunk גואטה ( ימין מזרחי ) . כל אחד מהם הפך xxunk תקשורתי בסמוך xxunk או xxunk . מי שיטען שאיש מהם לא סוחף אחריו מנדטים xxunk ; מי xxunk שהם xxunk בתקשורת כדי להחליש את הימין לא בהכרח xxunk ; מי שיטען שאין איש בלי תחליף לא יהיה רחוק xxunk .
#   אבל מי xxunk על התמונה הרחבה יגלה כאן מסה xxunk להתגלות xxunk . נתניהו הוא עדיין מגנט הקולות מספר אחת בישראל , אבל גם הוא לא יוכל לשאת את כל הימין על xxunk ( בטח לא כאשר הוא מכנה xxunk מימין לו xxunk xxunk " xxunk של השמאל " .
#   ב-1999 , xxunk לוי , איציק מרדכי , דן xxunk xxunk xxunk נטשו בזה אחר זה , הם הצליחו להעביר איתם פלח קטן אך מכריע של מצביעים למחנה ברק . קחו למשל רשימה היפותטית של יעלון , אורלי לוי xxunk גואטה ; או שריון של שלושתם ביש עתיד xxunk הציוני . האם אין שלושה , ארבעה מנדטים שהם יכולים להביא ? מי שצפה בשבוע שעבר xxunk " על משפחת גואטה ראה איך היא xxunk על xxunk xxunk ביותר של מצביעי ש"ס המסורתיים . יקשה מאוד לתאר את כל החבורה הזו כשמאל xxunk ערבים xxunk יהדות . לא כולם יחזרו על xxunk האיומה של לבני והרצוג xxunk ברשימה לבנה - חילונית - תל - אביבית . הימין הולך ודל , הולך xxunk xxunk אחיד . לא בטוח שביטן ואמסלם לבדם יספיקו .
#   הרגע הקשה ביותר של אבי גבאי מאז נבחר לראשות העבודה לא היה כאשר התבטא נגד פינוי יישובים , גם לא השבוע כאשר אמר xxunk שכח מה זה להיות יהודי . הוא אירע xxunk באוגוסט , בכנס חינוך גדול בחולון . גבאי הכין נאום סדור על המהפכה הנדרשת xxunk , נושא xxunk בו . עבר מבזק ועוד מבזק , כותרת xxunk xxunk , השעות xxunk אבל איש לא הזכיר את יו"ר העבודה , ואף מפיק לא ביקש ממנו להתראיין .
#   גבאי , אדם אלמוני למדי עד הקיץ האחרון וגם עכשיו הרבה פחות ידוע מלפיד , שמח מאז על כל הזדמנות ששמו מעורר רעש . דבר דומה קרה לנפתלי בנט בבחירות 2013 , שבהן xxunk . הוא התבטא בזכות סירוב פקודה לפנות יישובים , והליכוד פתח עליו xxunk רטורית כבדה . אבל מה שקרה בסקר שאחרי הוא שהבית היהודי זינק בעוד שלושה מנדטים : על כל תומך שלא אהב את הדברים נוספו שני מצביעים שעד ההתבטאות לא שמעו את השם בנט .
#   השאלה אם הפעם הרעש לא רב מדי . האם גבאי לא xxunk יותר מדי xxunk שלו , בסיס הבוחרים הותיק ? על פי xxunk xxunk יריביו , יש מצב שכן : גבאי xxunk בשתיקה יחסית מאז פורסמו דבריו xxunk בית בבאר שבע ; ואילו לפיד מימינו xxunk xxunk חגגו באולפנים . יו"ר יש עתיד הגיע מאפס xxunk תוך כמה שניות . " גבאי אמר שמי שלא מאמין xxunk הוא לא יהודי " , אמר לפיד בקול ישראל . " למה , סבא שלי לא היה יהודי ? למה xxunk ניסו להרוג אותו ? אפשר לפנות למרכז , אבל לא צריך לשחזר את xxunk הכי גרועים של נתניהו " . זה קצת משעשע כי לפיד עצמו חטף בשנה האחרונה משמאל על הניסיון xxunk שלו להיות תואם ביבי .
#   הניסיון לאסוף קולות בימין הרך ולשמור באותו זמן על הבסיס בשמאל הקשה הוא xxunk עדין מאוד . שלי יחימוביץ ' xxunk אותו בבחירות 2013 באופן מגושם שהסתיים xxunk xxunk . בניסיון לשבור ימינה היא xxunk את המחנה שלה . מצד שני , הרצוג לא ניסה כלל לפנות ימינה וסיים xxunk דרך מזהירה לתוך xxunk סתום .
#   איפה עומד גבאי ביניהם ? סקר מעניין ובלתי תלוי שלא פורסם עד עתה בדק לפני כמה שבועות את תגובות הציבור xxunk של גבאי שלפיה אין מקום לפנות יישובים גם לעת שלום . מקרב בוחרי הליכוד תמכו באמירה xxunk % מול 11 בלבד xxunk , אבל במפלגתו שלו רק 38 אחוז תמכו מול 55 % מתנגדים . האם האמירה xxunk או xxunk את הסיכוי xxunk לגבאי , נשאלו . בליכוד 25 אחוז אמרו xxunk גדל , xxunk – 27 אחוז שהוא ירד . זה משחק מסוכן , על שש נקודות : או xxunk מנדטים במקומות שלא הצביעו אמת כבר שני דורות , או xxunk במקומות הבודדים שבהם xxunk .
#   האמירה xxunk מהשבוע xxunk יותר , כי היא נוגעת בקודש הקודשים האידיאולוגי של השמאל , xxunk קיומו . לא מדובר כמובן בשאלה היהודית , אלא xxunk לנתניהו . לא הציטוט שבחר גבאי בעייתי , אלא xxunk . להגיד שנתניהו צדק – זה כבר בלתי xxunk אפילו xxunk ותיקים . מה הפלא שהרצוג , לבני , יחימוביץ ' ואחרים xxunk את הרוק .
#   ובכל זאת , יש גם תוכן . מדד הדמוקרטיה של המכון הישראלי לדמוקרטיה מעיד שגבאי אמר את האמת : בקרב בוחרי השמאל xxunk אחוז חושבים xxunk היהודי חזק מדי בחיי המדינה , לעומת 21 אחוז בלבד שחושבים כך בימין . מה אתה יותר , יהודי או ישראלי , נשאלו xxunk בהמשך . בקרב בוחרי השמאל מיעוט מבוטל של כעשרים אחוז הגדיר עצמו קודם xxunk , תמונת xxunk של המתרחש בימין .
#
#   במחיר הקרן
#   הקרן הקיימת לישראל xxunk השבוע xxunk דין מוות xxunk . קואליציה נדירה xxunk נגדה : רביב דרוקר ובנימין נתניהו , משה כחלון xxunk באופוזיציה . xxunk של ערוץ עשר על xxunk xxunk במוסדות הלאומיים xxunk את הקרקע ; כששר האוצר xxunk xxunk הוא נזכר במיליארדים xxunk xxunk xxunk xxunk עסקנים xxunk ; xxunk xxunk אמר לראש הממשלה בשפה בוטה מאוד xxunk , xxunk , היה מאוכזב ממנו לו שמע xxunk xxunk את כספי הקרן , נתניהו רתח .
#   נכון שהחוק xxunk לא דיבר על סגירת קק"ל , אבל ברגע שהכנסת הולכת על מהלך xxunk כזה , בניגוד להסכמות xxunk עבר , xxunk של המוסדות xxunk ( שאפשר להתווכח על מידת xxunk xxunk ) היה ידוע מראש .
#   בסוף זה נמנע בגלל פשרה xxunk שהוביל ח"כ בצלאל סמוטריץ ' . הוא גזר , מבחינתו , שני xxunk : גם שמירת המוסדות xxunk וגם 600 מיליון שקל מכספי קק"ל xxunk xxunk xxunk .
#
#   xxunk במשטרה
#   אורחים xxunk לאחרונה xxunk xxunk של משרדי המשטרה חזרו עם xxunk הבאות :
#   ראשית , xxunk המשטרה הודיע לפני כשנה שהחקירה נגד נתניהו תסתיים " בתוך שבועות " הוא אמנם טעה , אבל לא פחות מעניין מזה הוא כיצד ומדוע חשב שהחקירה תסתיים . נראה xxunk כבר אז הייתה לדווח על קיומה של תשתית ראייתית נגד נתניהו , אבל בתיק מצומצם ודל חשדות , אולי עבירה על חוק המתנות xxunk xxunk בלבד . מאז xxunk היריעה xxunk החשדות .
#   שנית , גורמים בכירים במערכת אכיפת החוק סבורים ש"זה יהיה מוזר מאוד אם xxunk את ארי הרו xxunk מדינה אבל בסוף לא xxunk לדין את נתניהו " . זה רמז ברור xxunk למי שצריך לקבל את ההחלטות בתיק 1000 ו-2000 .
#   שלישית , xxunk ההבנה xxunk של ליאור חורב היא טעות טקטית xxunk את המשטרה בקרב xxunk מסובך בזירה הפוליטית . מדוע הקרב הזה מתנהל בחודש האחרון ? אולי בגלל xxunk נתניהו בשבוע שעבר תואמה כבר לפני חודש . יש מי xxunk במשטרה xxunk הצעות החוק מבית ביטן - אמסלם , כמו גם xxunk נגד המפכ"ל xxunk , איננה מקרית .
#   רביעית , הכרעת המשטרה היא רק היומן של xxunk של xxunk להחלטה המשמעותית מכולן , זו של היועץ המשפטי לממשלה . החלטה אם להעמיד לדין פוליטיקאי בכיר מורכבת xxunk xxunk : התשתית הראייתית , הפרשנות המשפטית xxunk הציבורי . המשטרה אחראית לבדה על התשתית הראייתית , xxunk עם הפרקליטות את הניתוח המשפטי xxunk xxunk xxunk דן עם עצמו באינטרס הציבורי . על התשתית הראייתית אין חולק : נתניהו קיבל מתנות , וגם סידר xxunk xxunk . בפרשנות המשפטית הוא טוען שמדובר xxunk . המשטרה חושבת שזה שוחד , בפרקליטות עוד xxunk . האינטרס הציבורי הוא צומת xxunk החקירה xxunk xxunk טרם הגיעה אליו : האם נתניהו עוד יהיה ראש ממשלה ? האם אפשר לסגור תיק מתנות ? האם לטלטל את המדינה כולה xxunk בחירות בגלל תיק גבולי , אם יתברר ככזה ? אז , xxunk הליכוד והמשטרה ייראו xxunk רחוקה .
#   לא סחבק , מועמד
#   אם בשנת 2018 , אחרי כמעט עשרים שנה , שוב xxunk בבחירות זה מול זה בנימין נתניהו ואהוד ברק , זה יהיה אירוע תקדימי למדי . שחזור של קרב על ראשות הממשלה xxunk בפעם הקודמת כשעל xxunk העולם xxunk מנהיגים xxunk xxunk , xxunk xxunk , xxunk קלינטון xxunk xxunk ' איל xxunk xxunk xxunk ביותר היה קלטת וידאו – זה משהו שלא רואים כל יום .
#   xxunk ברק אומר לאמנון אברמוביץ ' שהוא מחזיק סקרים טובים , שהוא האדם xxunk xxunk ביותר להנהגה , שהוא מוכן xxunk עם גבי אשכנזי למען המדינה – למה הוא מתכוון ? ולמה עכשיו ?
#   איש לא לקח ברצינות את הודעות התמיכה xxunk של ברק באבי גבאי , xxunk בהרצוג . הוא לא חולם על קאמבק כדי לכהן כמספר שתיים של אזרח xxunk xxunk עשרים שנה אחריו . מי שהיה ראש ממשלה לא יסתפק בפחות . מצד שני , הסקרים ( חוץ מזה שברק מחזיק ) לא מלמדים לו טובות . הוא היה האיש המתאים לישראל של 1999 , החילונית יחסית xxunk בשלום , xxunk שינוי . ישראל 2018 , או 2019 , דתית יותר , xxunk יותר כלפי הערבים , לא מאמינה בשמאל . ברק אמנם מחזיק בניסיון בטחוני xxunk רב , אבל עמדותיו xxunk הופכים אותו מטרה נוחה בהרבה xxunk התעמולה של הליכוד מאשר גבאי או לפיד . מה הפלא שנתניהו בוחר xxunk דווקא אותו ולא את היריבים xxunk xxunk כרגע מולו .
#   הדברים , גם אם xxunk xxunk , מעידים שלפעמים החיים פשוטים : xxunk פתח xxunk xxunk שלו xxunk אותה בראיונות אינספור , הוא לא דיבר כאזרח מודאג אלא xxunk קאמבק . " מה עשיתי רע שאתה מציע לי את זה " ? נהג ברק לענות על השאלה xxunk אם xxunk לחזור . ובכן , כנראה שעשה רע . מצד שני , גם xxunk xxunk עדיין קשה לראות מפלגה חדשה xxunk יש מאין xxunk להתקרב לעשרים המנדטים שיש לגבאי ולפיד , כל אחד , בסקרים . זה נחמד בסקרים xxunk , אבל קשה בהרבה במציאות .
#   לכן כרגע הצהרת xxunk ברק פוגעת בעיקר באבי גבאי . דבריו מעידים שיו"ר העבודה לא נתפס בעיניו מועמד בעל סיכוי xxunk גיבוי שקט מהצד . xxunk ( xxunk ? ) שלו מלמדים xxunk xxunk יותר מסוף 2019 , xxunk המתוכנן . אבל המילים שלו הן סכין חד xxunk של מנהיג העבודה . איך יגיב גבאי ?
#   רגע ההכרעה של הקואליציה הנוכחית קרוב xxunk . הוא יגיע כבר בחודש ינואר הקרוב , xxunk תתבקש לאשר את תקציב 2019 . שר האוצר משה כחלון העביר מסרים חד xxunk : או שהתקציב עובר והממשלה xxunk את ימיה , או xxunk מיד . אין באמצע . אין לו כוונה להתחיל את xxunk xxunk של העברת תקציב בלי להגיע xxunk היעד הסופית . מיד או עד הסוף , xxunk או xxunk .
#   הרקע להכרעה הזו הוא גל שמועות נוסף על כוונה של נתניהו ללכת לבחירות בסוף מאי , מיד אחרי חגיגות השבעים על כל xxunk החיים , ביקורי xxunk מהעולם xxunk xxunk . נתניהו ממשיך להתעקש שאין לו כל כוונה להקדים את הבחירות , xxunk הפוליטי xxunk אומר שגם אין בכך כל טעם . אבל xxunk נמשכים : יושב ראש הקואליציה דוד ביטן שטען בתחילת השבוע שהקואליציה מתפרקת , xxunk הפוסטים xxunk , xxunk הבחירות .
#   עוד לפני כן יצטרך נתניהו xxunk להכרעה באשר לדרך שבה הוא מתכוון לנהל את הקרב המשפטי שלו . כרגע הוא עדיין מדבר בלשון כפולה : בישיבת סיעת הליכוד ביקש להפסיק עם המתקפות על המשטרה , אבל לא עשה דבר כדי לבלום את חוק ההמלצות ; שלשום הודיע שהוא מתנגד להורדת שכר המפכ"ל אבל לא העיר מילה xxunk ביטן - אמסלם . זה לא על דעתי , אמר למי xxunk אותו השבוע על הפעילות xxunk של xxunk . אבל זה לא עד כדי כך לא על דעתו xxunk להם משהו . עושה רושם שכרגע נוח לו עם המהלכים בחתימה נמוכה . בסביבתו יש מי xxunk xxunk את הווליום נגד המשטרה ויש מי שמציע xxunk אותו . התוצאה כרגע – xxunk באמצע .
#   זה תלוי גם xxunk בפרשות הפליליות . חקירתו אתמול והשבוע הקשה שעבר על מקורביו שמרון xxunk במשרדי להב 433 xxunk xxunk ההכרעה קרבה . בקרוב הוא יצטרך להחליט אם פניו למלחמה xxunk או להסכם פיוס עם רשויות אכיפת החוק . xxunk בפניו דילמה דומה עם התקשורת הישראלית הוא בחר באפשרות הראשונה . אבל התקשורת היא xxunk קל . המשטרה והפרקליטות זה כבר סיפור אחר לגמרי .
#
#   פגיעה xxunk
#   " תראה מה זה xxunk הדורות " , סימס גורם חרדי בערב שבו התפרסמה הקלטת החדשה של אריה דרעי . " הבן של הרב עובדיה סיפק סרט וידאו , אבל הבן של הרב שלום כהן הצליח להוציא רק xxunk " .
#   כן , יושב ראש ש"ס הפגין השבוע שוב xxunk מרשים xxunk לטובתו הקלטות מביכות . השיטה פשוטה : במקום לדבר על התוכן xxunk - xxunk , לדבר על ההקלטה . לא המסר , אלא המדיום . כך לפני שלוש שנים הפכו האשמות xxunk של הרב עובדיה xxunk ( " xxunk , גנב " ) xxunk מה עשו לך " . וכך , xxunk המתחייבים , גם השבוע . בזה אחר זה xxunk מקורביו וחברי סיעתו xxunk לדבר על xxunk שבו יושב ראש המפלגה מדבר נגד הראשון לציון . במקום זאת הם דיברו על " מעשה xxunk " xxunk . אפשר רק לשער מה היה קורה לו יאיר לפיד או נפתלי בנט היו xxunk בישיבה פנימית כשהם xxunk את גדולי רבני ש"ס xxunk כבוד , xxunk xxunk .
#   בוחרי ש"ס שנותרו במפלגה אחרי מות הרב עובדיה xxunk דרעי xxunk xxunk החרדי יותר . זה xxunk שרוצה שלום בית xxunk , מקפיד xxunk של רבנים xxunk xxunk חכמים . האם הם השתכנעו xxunk התקשורתי של מקורבי דרעי ?
#   הבעיה העיקרית של מנהיג ש"ס נחשפה השבוע במלוא xxunk : איום אלי ישי xxunk , כיסי ההתנגדות שלו במפלגה חוסלו , אבל דווקא אז , xxunk מראש על ההשוואה , במקום הטרור xxunk xxunk xxunk xxunk .
#   את xxunk דרעי בעקבות שתי חקירותיו הפליליות הריח היטב יעקב כהן , בנו של נשיא מועצת xxunk התורה , שכבר הפגין את כוחו בחיסול הקריירה הפוליטית של ח"כ יגאל גואטה . הריח אותה גם ח"כ יעקב xxunk , שעל פי עדותו של דרעי מתכנן בשקט לרשת את ההנהגה אם דרעי ייאלץ לפרוש . בשורת ראיונות בחודשים האחרונים הבהיר xxunk שכתב אישום xxunk פרישה , אמירה חוקתית שגרתית אבל מאוד בלתי שגרתית xxunk xxunk .
#   xxunk את החולשה גם xxunk של הרב עמאר .
#   שיתוף הפעולה בין כל הגורמים האלה הוביל את מה שזכה xxunk " השלום הספרדי " , פגישת פיוס בין xxunk הרבנים . הרחוב אהב , אבל דרעי זיהה כאן סכנה ברורה ומיידית . איך אמר פעם יצחק שמיר ? כל xxunk של יותר משני אנשים היא ניסיון xxunk קשר . לפחות במקרה הזה , העובדה שדרעי פרנואיד לא אומרת שלא רודפים אחריו . כשהוא מדבר על ניסיון הפיכה הוא איננו xxunk .
#   דרעי של הסיבוב השני איננו הרב - xxunk xxunk בפוליטיקה הישראלית . xxunk יפה ב"ידיעות אחרונות " לפני כמה שנים xxunk אותו xxunk המעגל , xxunk אחרי שנים רבות של xxunk xxunk מבין שהעולם המוכר לו השתנה לחלוטין . xxunk xxunk מנסים להסביר לו כבר שנים את חוקי המשחק החדשים : קבוצות ווטסאפ החליפו את קומץ העיתונאים שבהם שלט בעבר ביד xxunk , והוא גם צריך להניח שכל שיחה שלו xxunk . xxunk , תיעוד נוסף של דרעי ממתין בכמה בתים בהר נוף לפרסום קרוב .
# ...
#
#   הקול החרדי
#   " הם סגורים איתנו xxunk אחוז " . ' הם ' אלה החרדים , ' איתנו ' זה עם הליכוד , xxunk הוא אחד xxunk הבכירים של מפלגת השלטון .
#   חוזקו של הדבק בין נתניהו למפלגות החרדיות הוא אולי השאלה המכריעה ביותר של בחירות 2015 : אם הליכוד סגור עם ש"ס ויהדות התורה , זה אומר שביום השחור ביותר הוא מגיע אל הנשיא עם 52 ממליצים , מספר שהרצוג יתקשה מאוד להתקרב אליו . אם לא , הכל פתוח .
#   כדי לדעת את התשובה , כדאי לחזור חודשיים וחצי אחורה , לימים שבהם המערכת הפוליטית כולה xxunk xxunk פיו של מנהיג הציבור xxunk , הרב xxunk . נתניהו ביקש לפטר את לפיד xxunk את הבחירות , אבל ביקש בתמורה התחייבות של החרדים להמליץ עליו לנשיא אחרי הבחירות . החרדים xxunk קיום הבטחה כזו , אבל נתניהו – אדם זהיר מאוד – פיזר את הכנסת בכל זאת .
#   שבועיים אחר כך , הרב xxunk הורה xxunk שלא לשבת עם לפיד בכל ממשלה . זו הייתה התמורה לליכוד על xxunk לבחירות . בלי לפיד והחרדים גם יחד , אין להרצוג קואליציה . זו נקודה שחשוב לזכור אחרי עוד xxunk של סקרי סוף שבוע : נשיא המדינה הבהיר השבוע שלא xxunk ממליצים , אלא xxunk למי יש סיכוי להקים קואליציה . זה אומר , למשל , שגם אם באופן תיאורטי לפיד וליצמן ממליצים לנשיא על הרצוג , זה לא xxunk את ריבלין להמליץ עליו , אם השניים יבהירו שלא יישבו זה לצד זה .
#   בליכוד משוכנעים , כאמור , שכל הדיון הזה היפותטי . אותו שר בכיר הסביר xxunk החרדית xxunk xxunk xxunk בליל הבחירות , ממש כמו ב-2009 , xxunk פשוטה : יהדות התורה וש"ס אינן xxunk שהבחירות xxunk – שוב – למשאל עם על גיוס , xxunk xxunk בשבת . נוח להן שכולם xxunk xxunk .
#   במסגרת xxunk האלה נפגש השבוע נתניהו xxunk xxunk עם עיתונאים חרדיים , והבטיח xxunk את xxunk הפליליים ( מה שמעלה את השאלה : אם הוא כל כך בטוח בתמיכת החרדים , למה הוא xxunk הצהרות xxunk בו ברחוב החילוני ? ממה הוא חושש ) . במקביל , הגיע יו"ר המחנה הציוני אל ביתו של הרב אדלשטיין xxunk xxunk , xxunk הרבנים בציבור החרדי . xxunk כיפה סרוגה דווקא , הוא טען בפני הרב xxunk הפליליים על לומדי תורה xxunk לחוק באשמת הליכוד .
#   xxunk עוד אפשרות , שהחרדים מעדיפים במיוחד : ממשלת אחדות . נוח להם להיות הדבק בין שתי המפלגות הגדולות , בלי לחטוף יותר מדי משמאל ומימין , ועם נקמה xxunk בדמות xxunk האחים לפיד ובנט אל האופוזיציה . xxunk העיקרית היא xxunk לחבר בין זוהיר בהלול xxunk רגב , יוסי יונה וציפי חוטובלי , הולכת xxunk במהירות .
#
#   איפה עמונה שלנו
#   רגע לאחר השבעת הכנסת ה-19 , xxunk הראשונות xxunk , שמע אורי אורבך על ח"כ טרי חדש שכבר פרסם הודעה xxunk נגד השמאל . הוא סימס לדוברו הנאמן אסי xxunk : " אתה רואה ? כזה לא " .
#   xxunk הראשונה בכנסת אורבך חיפש xxunk את מה xxunk " xxunk שלנו " , או במילים אחרות : מאבק פוליטי xxunk , כולל כל האיומים הקואליציוניים xxunk , אבל לא בנושאים xxunk , xxunk , xxunk את הימין כל השנים . הוא האמין בעומק לבו וגם הבין פוליטית שהציונות הדתית תהיה בבעיה חמורה אם לא תעסוק בעוד נושאים חוץ xxunk , מחבלים xxunk ואבו - מאזן . xxunk הבחירות שהציע למפלגה ב-2009 הייתה " דתיים נורמליים " .
#   את xxunk הגדולה הוא לא מצא , אבל בהחלט תפס כמה xxunk : אורבך דחף בכל הכוח לתמיכה ברב דוד סתיו לתפקיד הרב הראשי , xxunk ריבלין לנשיא xxunk ברקת לראשות העירייה , כל אלה בניגוד לאינטרס הפוליטי של המפלגה , אבל בהתאם לאינטרס הציבורי . הוא פעל לשילוב של עוד גורמים xxunk המפה , למשל הרב חיים אמסלם , בבית היהודי ; קידם הקמת xxunk שבת xxunk משותפים xxunk xxunk ; xxunk אחד הח"כים הבודדים , לצד שלי יחימוביץ ' , xxunk בוועדת הכספים xxunk מס xxunk xxunk , xxunk נעלמה xxunk על שולחן הוועדה .
#   העיסוק xxunk בנושאים xxunk או xxunk ( xxunk היה איש שמאל חברתי , בניגוד xxunk xxunk xxunk את רוב xxunk xxunk ) הוא אחד המרכיבים xxunk xxunk עכשיו xxunk xxunk , בקרב xxunk xxunk עליה פתאום מול נתניהו . אפשר לנחש שאם אורבך היה יושב עכשיו בישיבות הקמפיין הוא היה מציע לדרוש את משרד החינוך במקום המשרד לביטחון הפנים , ואת משרד התרבות במקום את משרד הדתות . הנה xxunk שהוא היה מאמץ : זה לא מקרה xxunk הגדולה xxunk קוראים " הבית היהודי " , xxunk xxunk כבר שנים קוראים " האיחוד הלאומי " .
#   פוליטיקה היא גם עניין של xxunk . אורבך , יהודי xxunk , xxunk לבנט ושקד xxunk xxunk , אף xxunk xxunk היה אולי קרוב יותר xxunk xxunk . זה קרה בגלל שהוא לא האמין אף פעם בפוליטיקה xxunk של נאומים xxunk xxunk . מותר לנחש שהוא לא היה משתגע על xxunk xxunk שראש מפלגתו אימץ xxunk עם פרוץ הבחירות האחרונות : xxunk שלי " xxunk כבר " , xxunk xxunk xxunk xxunk דיבה xxunk צעקות באולפנים . למה הם כל כך עצבניים , היה תמה . xxunk , הוא היה ממליץ למפלגה שלו לחזור לעשות פוליטיקה בדרכי xxunk , לא בדרכי xxunk .
#   החג הבא עלינו xxunk הוא xxunk , xxunk יום אחריו יגיע יום כיפור . יום כיפור של הכתבים הפוליטיים כמובן .
#   אז רגע לפני xxunk הזה שוב תופס גובה , חשוב להבהיר משהו :
#   xxunk הפוליטי יש כל מיני תפקידים , xxunk xxunk של xxunk ישראלים ממש איננו אחד מהם . כתב פוליטי הוא לא xxunk , גם לא פסיכולוג ואפילו לא סוקר . התפקיד שלו הוא להסביר ולחשוף מה עושים הפוליטיקאים xxunk , להזכיר מה חשבו בעבר , ממש לא לנבא איך יצביעו הישראלים בעתיד .
#   רק xxunk מוחלט xxunk xxunk על איזה צד xxunk אזרחי ישראל xxunk . פרשן טוב צריך להסביר כמה מנדטים צריך נתניהו כדי להרכיב ממשלה , האם הרצוג יכול לבנות קואליציה ומדוע כחלון נמנע xxunk על מועמד . הוא צריך לתת לציבור את המידע המלא , אחרי xxunk xxunk xxunk xxunk . זה התפקיד ולא אחר . xxunk קל שיהיה .
#   בכל מסע בחירות מגיע הרגע הקבוע הזה שבו , xxunk xxunk אדירה , נתניהו xxunk xxunk מלא xxunk . האם עשרת הימים האחרונים היו הרגע הזה ? עד אז , הכול עבד לנתניהו . כולם חשבו שהוא כבד xxunk , אבל הוא xxunk xxunk xxunk xxunk את האינטרנט ; במקום שבנט ייקח לו את החילונים , הוא גנב לבנט את הדתיים - לאומיים ; במקום שליברמן xxunk אותו , הוא xxunk מליברמן התחייבות לשבת בממשלת ימין .
#   אבל אז xxunk עשרת הימים xxunk של הליכוד . וכולם , כמובן , תוצרת בית : זה החל בסרטון xxunk , xxunk - xxunk משהו , של מושיק xxunk במעון בבלפור . המשיך במתקפה המשונה , חסרת xxunk , על מני נפתלי , xxunk של xxunk - xxunk אל האולפנים . אחר כך הגיע xxunk הדרישה חסרת - הסיכוי xxunk את דו"ח הדיור , יומיים של פסטיבל בחסות מבקר המדינה , חקירה פלילית על בקבוקים , xxunk בקיסריה וגם זו רשימה חלקית .
#   סקרי דעת הקהל , xxunk הסערה , מלמדים על כשני מנדטים – 65 אלף איש – שנטשו את הליכוד ; ועוד כמספר הזה מצביעים xxunk לפי שעה ללכת xxunk ביום הבחירות . xxunk בליכוד יגידו xxunk רעה מאוד . xxunk יגידו xxunk xxunk כבר מאחורי נתניהו . xxunk ימתינו לנאום נתניהו בוושינגטון . בסוף השבוע הבא אפשר יהיה לדעת לאן כל זה הולך . אפשר להניח בסבירות גבוהה שגם אם יזכה בבחירות צפויה לנתניהו שנה רעה xxunk : עם קואליציה ימנית xxunk , עתירת אויבים , או ממשלת רוטציה מסוכסכת ; עם xxunk משטרה בפתח xxunk בבלפור .
#   נתניהו משוכנע , גם עכשיו , שהוא הדבר הטוב ביותר שקרה לימין . שהוא חזק מסך מפלגתו , מסך מחנהו . מי אם לא אני יעמוד מול האמריקנים , מול ההסכם הנורא xxunk עם האיראנים , אמר השבוע למי שאמר ברכב , בדרכו חזרה xxunk במעלה - אדומים . גם xxunk xxunk הקליטה xxunk אפשר היה לשמוע שהוא עצבני . נתניהו מתפוצץ כשהוא מקבל את הדיווחים על הנעשה בשיחות הגרעין xxunk , ואחר כך את התמלילים של מהדורות החדשות על מני נפתלי . הוא משוכנע שהתקשורת xxunk את העם באותו xxunk שבו כמה עיתונאים משוכנעים שהוא xxunk את העם xxunk xxunk . xxunk , הוא משוכנע , תקום כאן ממשלה שתכשיר כניעה אמריקנית xxunk .
#   אבל הגרעין האיראני לא מטריד כל כך את בוחרי הליכוד , ולכן , xxunk בשבוע הבא על במת הקונגרס , מול xxunk xxunk הדמוקרטי xxunk , נתניהו יצטרך לשאת את נאום חייו . הוא יצטרך לטלטל את הישראלים באופן כזה xxunk מהם את הדיור , את xxunk האף ואת כל שאר הפרשות . אחרת , גם הנסיעה xxunk שבה xxunk כל כך הרבה תקוות עוד עשויה xxunk על ראשו . יש לו xxunk שבת עד רביעי , ארבעה ימים ( ועוד חמש דקות ) , ארבע כותרות xxunk , לשנות את הכיוון של מערכת הבחירות .
#
#   הרצוג חושש לסיים כמו ברק
#   נניח xxunk הציוני יזכה בבחירות האלה לניצחון מוחץ על הליכוד , 6 - 5 מנדטים xxunk . xxunk בראש את החגיגות בכיכר רבין ; את xxunk xxunk xxunk במטה ; את נאומי הניצחון של לבני והרצוג ; את נתניהו פורש שלא על מנת לחזור . כל זה טוב xxunk , אבל איך יוצאת מזה קואליציה ?
#   התקדים xxunk ביותר מבחינתו של הרצוג הוא זה של אהוד ברק ב-1999 , וזה אינו תקדים מעודד מבחינתו . בניגוד ליו"ר המחנה הציוני , בבוקר שאחרי הניצחון המכריע ( 26 - 19 על הליכוד ) ברק לא היה צריך xxunk קואליציות אצל הנשיא , כי זכה בבחירות הישירות לראשות הממשלה . אבל בבואו להרכיב ממשלה , הוא גילה כנסת חדשה xxunk xxunk , כמו זו xxunk כנראה בעוד שבועיים : כנסת עם מרצ xxunk ועם לפיד ( xxunk ) , עם מפלגת מרכז בראשות שר שעזב את הליכוד בגלל נתניהו ; עם מפלגות xxunk xxunk xxunk שלטון . לאהוד ברק לקח כמעט חודשיים תמימים להרכיב קואליציה , פרק זמן ארוך בהרבה מזה xxunk לה כדי xxunk . ש"ס ומרצ לא xxunk xxunk : מרצ xxunk לטובת השלום , ש"ס xxunk בגלל תהליך השלום . xxunk של יותר xxunk ח"כים , נותרו לברק אחרי שנה 30 ח"כים בלבד .
#   הרצוג לא זקוק xxunk הזו . הוא היה מזכיר הממשלה ההיא . במשך חודשיים תמימים ניסה בכל כוחו לפתור את המשבר הקואליציוני xxunk בתולדות ישראל , משבר העברת xxunk בשבת . החומרים שמהם הוא נדרש להכין את xxunk הזה הם xxunk xxunk . בקיצור : אם לא תהיה התרסקות רבתי של גוש נתניהו - בנט - ישי , הוא יוכל להגיע לראשות הממשלה רק באמצעות רוטציה . אין לו דרך אחרת xxunk את מעגל xxunk שכולל את ליברמן ומרצ , החרדים ולפיד , כחלון xxunk .
#   את עיקר xxunk תולה הרצוג xxunk . הוא מאמין xxunk הטובים , xxunk xxunk xxunk הפוליטיים xxunk xxunk אותם בממשלתו . השבוע , xxunk כיפה סרוגה , הוא xxunk את xxunk xxunk של יעקב ליצמן , גדול תומכיו של נתניהו במפלגות החרדיות .
#   ספק אם ליצמן הוא הבעיה של המחנה הציוני . הנה עוד תזכורת xxunk הקודם : רגע לפני xxunk מאחוריו הדלת xxunk של xxunk מעשיהו , xxunk תומכיו xxunk אותו , אריה דרעי בחר להגיד משפט אחד : " אני גם רוצה לבקש xxunk סליחה xxunk xxunk xxunk זקן ראשי הישיבות הרב אליעזר מנחם xxunk xxunk xxunk xxunk xxunk ימיו על הצער xxunk לו , על xxunk xxunk לו , על כל זה אני מבקש ממנו אנא , xxunk בלי כוונה , מחל לי xxunk לי xxunk לי " . דרעי התכוון להחלטת ש"ס להיכנס לממשלת רבין למרות התנגדותו העזה של הרב xxunk . זו הטראומה xxunk של דרעי . xxunk לשמאל הייתה , בעיניו , xxunk נפילתו .
#   ולכן , קשה להאמין שדרעי xxunk להיכנס שוב לבד לממשלת עבודה - מרצ . ישי יגנוב לו את הרחוב הספרדי הימני , הרבנים האשכנזים יעשו שמות במעמדו . יותר משהם רוצים את הליכוד הם מסתייגים מהשמאל , ועוד יותר מזה עוינים את ציפי לבני , שאותה הם מזהים עם חקיקה חילונית מוצהרת . xxunk , גם xxunk העזה של דרעי לנתניהו לא xxunk לו לסכן הכול בשביל ממשלה xxunk .
#   ובכל זאת , לנתניהו יש סיבה לדאגה מהעובדה שעד לרגע זה , שמונה - עשר יום לפני הבחירות , אין לו יותר מ-40 ממליצים בטוחים לנשיא . כחלון , דרעי , ליברמן וליצמן xxunk עם התמיכה בממשלת ימין אבל איש מהם לא התחייב על כך במפורש , למרות מחירים xxunk שחלקם משלם על כך . הם עוד לא xxunk על החלום להשתתף במכרז של המדינה , על xxunk בית הנשיא .
#
#   האלגוריתם קובע : כולם חושבים כמוני
#   xxunk הבולטת של בחירות 2015 עד עתה היא תהליך xxunk שעבר על הבוחר הישראלי : הוא יכול להרשות לעצמו xxunk בין נתניהו לבנט , או בין הרצוג ללפיד , או בין אחד מהם לבין xxunk xxunk , אבל כמעט שאין xxunk בין הגושים .
#   ארד xxunk , xxunk xxunk חברתיות , מציע הסבר מאלף לתופעה הזו , וגם הפעם הכול באשמת מארק צוקרברג . האלגוריתם של פייסבוק מזהה את xxunk של xxunk xxunk לו מה שהוא אוהב לראות . עשית לייק xxunk של xxunk xxunk ? xxunk שלך xxunk xxunk מכל צבע . xxunk xxunk אחר xxunk xxunk ? פייסבוק xxunk אותך על כל תמונה שהיא מעלה .
#   דבר דומה קורה גם במונחים פוליטיים . פייסבוק מקפידה מאוד xxunk מעין xxunk פוסטים שהוא לא מסכים איתם . אם אתה xxunk בהתנחלות xxunk ביד קשה נגד חמאס , רוב הסיכויים xxunk xxunk xxunk את הפוסט השמאלני xxunk xxunk xxunk xxunk . ובקיצור : משיקולים כלכליים של המיליארדר xxunk , כולנו xxunk xxunk ואפילו לא יודעים למה . מי שלא מאמין מוזמן להתקשר xxunk מרצ הקרוב למקום xxunk , רק כדי לשמוע ממנו xxunk - xxunk מצביעים זהבה גלאון .
#   תומכי xxunk המהפך xxunk xxunk : בסופו של השבוע הטוב ביותר בקמפיין של נתניהו , כשכולם מדברים רק על איראן ועל xxunk xxunk בקונגרס , כשהרצוג החיוור שוגה בעזה , מצהיר שאין לו מושג על הגרעין ובאופן כללי הולך לאיבוד ; כשכחלון ולפיד לא רלבנטיים ; בסופו של השבוע הזה הליכוד בקושי מצליח xxunk למחנה הציוני . מכאן זה רק ילך xxunk .
#   תומכי xxunk ניצחון הימין xxunk כך : אחרי שבועות של xxunk אכזרית , אחרי שני דו"חות מבקר איומים , בעיתוי אסטרטגי , אחרי בדיקות , בקבוקים , xxunk xxunk , נתניהו הצליח להפוך את המגמה . לראשונה זה זמן רב הליכוד לא יורד אלא עולה , הפער מהרצוג בהתאמה לראשות הממשלה מתרחב , לא מצטמצם . מכאן זה רק ילך xxunk .
#   כמובן שלאיש אין מושג ירוק איזו xxunk נכונה . העניין הוא , xxunk של שתי המפלגות הגדולות ( לפעמים xxunk במובן xxunk יותר של המילה ) כבר xxunk xxunk : xxunk xxunk , האישי , נגד נתניהו , הגיע כנראה לרגע השיא שלו xxunk , אבל אחרי החלטת xxunk לא לחקור את נתניהו אישית , זה מאחורינו ; נתניהו כבר אחרי רגע השיא של הנאום בקונגרס , xxunk לא תישאר xxunk בשבוע הבא .
#   על מה ידברו בשבוע הבא ? אם לנתניהו יש אומץ , xxunk ביטוח הוא צריך להודיע על xxunk לעימות מול הרצוג בשלישי הבא . בראשון ידברו על הסכמתו , בשני xxunk לעימות , בשלישי הוא xxunk , ברביעי xxunk עד xxunk – והנה xxunk מערכת הבחירות . זה צעד כל כך הגיוני מבחינתו של נתניהו , עד שאפשר להיות די בטוח שהוא לא xxunk בו .
#   ציר האחים החדש
#   המילים החשובות ביותר בהכרזה של אריה דרעי על תמיכה בנתניהו היו דווקא xxunk xxunk לה : " אין מה לעשות " , אמר יו"ר ש"ס , xxunk . תוהה בוודאי איך כל שונאיו של ראש הממשלה xxunk ללכת xxunk xxunk על תמיכה בו , xxunk הרחוב . קודם בנט , אחר כך ליברמן , עכשיו הוא .
#   האם כחלון הבא בתור ? מי xxunk xxunk לסיכום כזה יכול xxunk xxunk xxunk של נתניהו לתקוף את " כולנו " . ההחלטה הזו מנוגדת כל כך לאינטרס האלקטורלי שלו , עד שאפשר לחשוב שהיא תואמת אינטרס פוליטי ביום שאחרי .
#   המתנה שהעניק דרעי לנתניהו חשובה משתי סיבות : הראשונה , היא מעניקה לו יתרון חשוב xxunk הממליצים . נתניהו ניצב בסוף השבוע האחרון בפני איום חמור : גם הפסד בקרב על הרשימה הגדולה , וגם הפסד בקרב הממליצים xxunk . השילוב xxunk - מרצ - לפיד זכה לקצת יותר מ-40 מנדטים , בעוד xxunk נתניהו - בנט - ישי זכה לקצת פחות מ-40 .
#   במצב כזה , אם החרדים , ליברמן וכחלון היו יושבים על הגדר – הרכבת הממשלה הייתה הולכת כנראה להרצוג . xxunk מתחייב להמליץ על נתניהו הוא קובע למעשה xxunk יהיו יותר ממליצים רק אם ליברמן וכחלון xxunk עליו xxunk , לא די בשתיקה xxunk סוד בסלון של ריבלין .
#   הסיבה השנייה היא xxunk להמליץ על נתניהו , גם אם הגיעה xxunk xxunk ואחרי לחץ כבד מהרחוב , xxunk ציר xxunk חדש , ציר ליברמן - כחלון - דרעי , שיכול היה לכפות על נתניהו רוטציה .
#   ועדיין , אפשר לתהות אם להאמין ליו"ר ש"ס , מי שבשנה האחרונה כבר xxunk את הרצוג , פרש מהפוליטיקה שלא על מנת לחזור ובסוף חזר גם חזר משתי ההצהרות . xxunk המר המנוח xxunk האמירה : " xxunk xxunk עם הליכוד בקואליציה , אבל לא xxunk xxunk איתו באופוזיציה " . דרעי אולי ינסה xxunk אותה בקרוב .
#
# y: LMLabelList
#
# Path: data/amit;
#
# Test: None, model=SequentialRNN(
#   (0): AWD_LSTM(
#     (encoder): Embedding(12917, 400, padding_idx=1)
#     (encoder_dp): EmbeddingDropout(
#       (emb): Embedding(12917, 400, padding_idx=1)
#     )
#     (rnns): ModuleList(
#       (0): WeightDropout(
#         (module): LSTM(400, 1150, batch_first=True)
#       )
#       (1): WeightDropout(
#         (module): LSTM(1150, 1150, batch_first=True)
#       )
#       (2): WeightDropout(
#         (module): LSTM(1150, 400, batch_first=True)
#       )
#     )
#     (input_dp): RNNDropout()
#     (hidden_dps): ModuleList(
#       (0): RNNDropout()
#       (1): RNNDropout()
#       (2): RNNDropout()
#     )
#   )
#   (1): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=12917, bias=True)
#     (output_dp): RNNDropout()
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7efe7446b378>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('data/amit'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True)], callbacks=[RNNTrainer
# learn: ...
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): Embedding(12917, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(12917, 400, padding_idx=1)
#   )
#   (2): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=12917, bias=True)
#     (output_dp): RNNDropout()
#   )
# )], add_time=True)

# %%
learn_amit.export("learn_amit.pkl")
